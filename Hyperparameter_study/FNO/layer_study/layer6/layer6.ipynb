# %%
"""
FNO-DeepONet Black-Scholes Solver
Optimized for 2D Grid branch data (u: 11 days x 34 deltas) and continuous trunk coordinates (M, tau)
"""

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import h5py
import numpy as np
import time
import matplotlib.pyplot as plt

# ==========================================
# NETWORK ARCHITECTURE (FNO-DeepONet)
# ==========================================

class SpectralConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1
        self.modes2 = modes2

        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))

    def compl_mul2d(self, input, weights):
        # (batch, in_channel, x, y), (in_channel, out_channel, x, y) -> (batch, out_channel, x, y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        # Compute 2D Real Fast Fourier Transform
        x_ft = torch.fft.rfft2(x)

        # Multiply relevant Fourier modes
        out_ft = torch.zeros(batchsize, self.out_channels, x.size(-2), x_ft.size(-1), dtype=torch.cfloat, device=x.device)
        
        # Lower Fourier modes
        out_ft[:, :, :self.modes1, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        
        # Upper Fourier modes
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)

        # Return to spatial domain
        x = torch.fft.irfft2(out_ft, s=(x.size(-2), x.size(-1)))
        return x


class FNO_Branch(nn.Module):
    def __init__(self, modes1=4, modes2=12, width=32, p_dim=128):
        super().__init__()
        self.modes1 = modes1 # Truncated modes for 'days'
        self.modes2 = modes2 # Truncated modes for 'deltas'
        self.width = width
        
        # Lifting layer (1 channel -> width channels)
        self.fc0 = nn.Conv2d(1, self.width, 1) 
        
        # FNO Blocks
        self.conv0 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        
        # 1x1 Convolution bypasses for residual connections
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)
        
        # Projection to DeepONet basis dimension
        # The flattened grid size will be width * 11 * 34
        self.fc1 = nn.Linear(self.width * 11 * 34, 256)
        self.fc2 = nn.Linear(256, p_dim)

    def forward(self, x):
        # Reshape flat 374 vector into 2D Grid: (batch, channels, days, deltas)
        x = x.view(-1, 1, 11, 34)
        
        x = self.fc0(x)
        
        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = F.gelu(x1 + x2)
        
        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = F.gelu(x1 + x2)
        
        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = F.gelu(x1 + x2)
        
        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = F.gelu(x1 + x2)
        
        # Flatten and project
        x = x.view(x.shape[0], -1) 
        x = F.gelu(self.fc1(x))
        x = self.fc2(x)
        return x


class PINN_MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim, is_positive=True):
        super().__init__()
        layers = []
        
        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(nn.LayerNorm(hidden_dim))
        layers.append(nn.Tanh())
        
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(nn.LayerNorm(hidden_dim))
            layers.append(nn.Tanh())
            
        layers.append(nn.Linear(hidden_dim, output_dim))
        
        if is_positive:
            layers.append(nn.Softplus())
            
        self.net = nn.Sequential(*layers)
        
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)
                
    def forward(self, x):
        return self.net(x)


class FNO_DeepONet(nn.Module):
    def __init__(self, hidden_dim, num_layers, p_dim, fno_width=32):
        super().__init__()
        # 1. New FNO Branch
        self.branch = FNO_Branch(
            modes1=4, 
            modes2=12, 
            width=fno_width, 
            p_dim=p_dim
        )
        
        # 2. Standard MLP Trunk for continuous variables (M, tau)
        self.trunk = PINN_MLP(
            input_dim=2, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=p_dim, 
            is_positive=False
        )
        
        self.bias = nn.Parameter(torch.zeros(1))
        self.softplus = nn.Softplus()

    def forward(self, u, M, tau):
        branch_out = self.branch(u)
        
        trunk_input = torch.cat([M, tau], dim=1)
        trunk_out = self.trunk(trunk_input)
        
        # Compute the dot product across the basis dimension (p_dim)
        dot_product = torch.sum(branch_out * trunk_out, dim=1, keepdim=True)
        
        # Add bias and enforce positivity for volatility
        sigma = self.softplus(dot_product + self.bias)
        return sigma


class DeepBS_Solver(nn.Module):
    def __init__(self, hidden_dim=128, num_layers=4, p_dim=128):
        super().__init__()
        
        # Network 1 is now an FNO-DeepONet
        self.nn1 = FNO_DeepONet(
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            p_dim=p_dim,
            fno_width=32
        )
        
        # Network 2 remains a standard PINN_MLP predicting option price
        self.nn2 = PINN_MLP(
            input_dim=5, 
            hidden_dim=hidden_dim, 
            num_layers=num_layers, 
            output_dim=1, 
            is_positive=True
        )

    def forward(self, M, tau, u, r, q):
        sigma = self.nn1(u, M, tau)
        nn2_input = torch.cat([M, tau, r, q, sigma], dim=1)
        v_hat = self.nn2(nn2_input)
        
        return sigma, v_hat


# ==========================================
# LOSS FUNCTIONS (Unchanged)
# ==========================================

def compute_derivatives(v_hat, M, tau):
    dv_dM = torch.autograd.grad(
        outputs=v_hat, inputs=M, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    d2v_dM2 = torch.autograd.grad(
        outputs=dv_dM, inputs=M, 
        grad_outputs=torch.ones_like(dv_dM),
        create_graph=True, retain_graph=True
    )[0]
    
    dv_dtau = torch.autograd.grad(
        outputs=v_hat, inputs=tau, 
        grad_outputs=torch.ones_like(v_hat),
        create_graph=True, retain_graph=True
    )[0]
    
    return dv_dM, d2v_dM2, dv_dtau


def generate_boundary_points(batch_size, u, r, q, device, M_max=3.0, tau_max=5.32):
    indices = torch.randint(0, u.size(0), (batch_size,), device=device)

    M_term = torch.rand(batch_size, 1, device=device) * M_max
    tau_term = torch.zeros(batch_size, 1, device=device)

    M_lower = torch.zeros(batch_size, 1, device=device)
    tau_lower = torch.rand(batch_size, 1, device=device) * tau_max

    M_upper = torch.full((batch_size, 1), M_max, device=device)
    tau_upper = torch.rand(batch_size, 1, device=device) * tau_max

    return {
        'terminal': (M_term, tau_term, u[indices], r[indices], q[indices]),
        'lower': (M_lower, tau_lower, u[indices], r[indices], q[indices]),
        'upper': (M_upper, tau_upper, u[indices], r[indices], q[indices]),
    }


def pinn_loss_fn(
    model, M, tau, u, r, q, v_true, mask, lambdas,
    device, num_boundary=256,
    M_max=3.0, tau_max=5.32
):
    sigma_hat, v_hat = model(M, tau, u, r, q)

    # ----------------
    # Data Loss
    # ----------------
    squared_errors = (v_hat - v_true) ** 2
    loss_data = torch.sum(squared_errors * mask) / (torch.sum(mask) + 1e-8)

    # ----------------
    # PDE Loss (tau is in YEARS; no scaling factor needed for time derivative)
    # ----------------
    dv_dM, d2v_dM2, dv_dtau = compute_derivatives(v_hat, M, tau)

    pde_residual = (
        -dv_dtau
        + 0.5 * (sigma_hat ** 2) * (M ** 2) * d2v_dM2
        + (r - q) * M * dv_dM
        - r * v_hat
    )
    loss_pde = torch.mean(pde_residual ** 2)

    # ----------------
    # Arbitrage Loss
    # ----------------
    loss_arb = torch.mean(F.relu(-dv_dM)) + torch.mean(F.relu(-d2v_dM2))

    # ----------------
    # Boundary Conditions 
    # ----------------
    boundaries = generate_boundary_points(
        num_boundary, u, r, q, device, M_max=M_max, tau_max=tau_max
    )

    M_t, tau_t, u_t, r_t, q_t = boundaries['terminal']
    M_t.requires_grad_(True)
    tau_t.requires_grad_(True)
    _, v_term = model(M_t, tau_t, u_t, r_t, q_t)
    loss_term = F.mse_loss(v_term, F.relu(M_t - 1.0))

    M_l, tau_l, u_l, r_l, q_l = boundaries['lower']
    M_l.requires_grad_(True)
    tau_l.requires_grad_(True)
    _, v_lower = model(M_l, tau_l, u_l, r_l, q_l)
    loss_lower = F.mse_loss(v_lower, torch.zeros_like(v_lower))

    M_u, tau_u, u_u, r_u, q_u = boundaries['upper']
    M_u.requires_grad_(True)
    tau_u.requires_grad_(True)
    _, v_upper = model(M_u, tau_u, u_u, r_u, q_u)
    v_upper_true = M_u * torch.exp(-q_u * tau_u) - torch.exp(-r_u * tau_u)
    loss_upper = F.mse_loss(v_upper, v_upper_true)

    # ----------------
    # Total
    # ----------------
    loss_total = (
        lambdas.get('data', 1.0) * loss_data +
        lambdas.get('pde', 0.1) * loss_pde +
        lambdas.get('arb', 0.1) * loss_arb +
        lambdas.get('term', 1.0) * loss_term +
        lambdas.get('lower', 1.0) * loss_lower +
        lambdas.get('upper', 1.0) * loss_upper
    )

    loss_dict = {
        'data': loss_data.item(),
        'pde': loss_pde.item(),
        'arb': loss_arb.item(),
        'term': loss_term.item(),
        'lower': loss_lower.item(),
        'upper': loss_upper.item(),
        'total': loss_total.item()
    }

    return loss_total, loss_dict


# ==========================================
# DATASET & COLLATOR (Unchanged)
# ==========================================

class ChronologicalOptionDataset(Dataset):
    def __init__(self, h5_path, split='train', load_to_memory=True):
        self.h5_path = h5_path
        self.load_to_memory = load_to_memory
        
        with h5py.File(h5_path, 'r') as f:
            total_rows = f['target_v'].shape[0]
            self.u_dim = f['branch_u'].shape[1]
            
            train_end = int(0.80 * total_rows)
            val_end = int(0.90 * total_rows)
            
            if split == 'train':
                self.start_idx, self.end_idx = 0, train_end
            elif split == 'val':
                self.start_idx, self.end_idx = train_end, val_end
            elif split == 'test':
                self.start_idx, self.end_idx = val_end, total_rows
            else:
                raise ValueError("Split must be 'train', 'val', or 'test'.")
            
            self.length = self.end_idx - self.start_idx
            
            if load_to_memory:
                self.branch_u = f['branch_u'][self.start_idx:self.end_idx]
                self.trunk_y = f['trunk_y'][self.start_idx:self.end_idx]
                self.target_v = f['target_v_normalized'][self.start_idx:self.end_idx]
                
        print(f"Loaded {split}: {self.length} samples")

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        return (
            torch.tensor(self.branch_u[idx], dtype=torch.float32),
            torch.tensor(self.trunk_y[idx], dtype=torch.float32),
            torch.tensor(self.target_v[idx], dtype=torch.float32)
        )
    
    def get_u_dim(self):
        return self.u_dim


def create_pinn_collate_fn(colloc_ratio=0.2, M_max=3.0, tau_max=5.32, points_per_u=10):
    def collate_fn(batch):
        u_true = torch.stack([item[0] for item in batch])
        y_true = torch.stack([item[1] for item in batch])
        v_true = torch.stack([item[2] for item in batch])

        if v_true.dim() == 1:
            v_true = v_true.unsqueeze(1)

        M_true = y_true[:, 0:1]
        tau_true = y_true[:, 1:2]
        r_true = y_true[:, 2:3]
        q_true = y_true[:, 3:4]

        num_true = len(batch)

        if colloc_ratio > 0.0:
            target_num_colloc = max(1, int(num_true * (colloc_ratio / (1.0 - colloc_ratio))))
            num_unique_u = max(1, target_num_colloc // points_per_u)
            actual_num_colloc = num_unique_u * points_per_u

            idx = torch.randint(0, num_true, (num_unique_u,))
            u_base = u_true[idx]
            r_base = r_true[idx]
            q_base = q_true[idx]
            
            u_colloc = u_base.repeat_interleave(points_per_u, dim=0)
            r_colloc = r_base.repeat_interleave(points_per_u, dim=0)
            q_colloc = q_base.repeat_interleave(points_per_u, dim=0)
            
            M_colloc = torch.rand(actual_num_colloc, 1) * M_max
            tau_colloc = torch.rand(actual_num_colloc, 1) * tau_max
            v_colloc = torch.zeros(actual_num_colloc, 1)

            M_final = torch.cat([M_true, M_colloc])
            tau_final = torch.cat([tau_true, tau_colloc])
            u_final = torch.cat([u_true, u_colloc])
            r_final = torch.cat([r_true, r_colloc])
            q_final = torch.cat([q_true, q_colloc])
            v_final = torch.cat([v_true, v_colloc])
            mask = torch.cat([torch.ones(num_true, 1), torch.zeros(actual_num_colloc, 1)])
            
        else:
            M_final, tau_final, u_final = M_true, tau_true, u_true
            r_final, q_final, v_final = r_true, q_true, v_true
            mask = torch.ones(num_true, 1)

        return M_final, tau_final, u_final, r_final, q_final, v_final, mask

    return collate_fn

# ==========================================
# TRAINING
# ==========================================

def train_model():
    seed = 42
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 
    np.random.seed(seed)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: {device}")
    
    config = {
        'epochs_adam': 100,      
        'epochs_lbfgs': 50, 
        'batch_size': 256,  #changed
        'lr': 1e-3,
        'hidden_dim': 64,
        'num_layers': 6,
        'p_dim': 64,             
        'colloc_ratio': 0.2,
        'points_per_u': 20,      #changed
        'num_boundary': 128, 
        'grad_clip': 1.0,
        'M_max': 3.0,
        'tau_max': 5.32,
        'patience_adam': 3,     #changed
        'patience_lbfgs': 3,    #changed
    }
    
    #changed
    lambdas = {'data': 1.0, 'pde': 0.5, 'arb': 0.5, 'term': 0.0, 'lower': 0.0, 'upper': 0.0}
    
    print("Loading datasets...")
    train_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'train')
    val_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'val')
    test_ds = ChronologicalOptionDataset('../../wrds_data/deeponet_tensors.h5', 'test') 
    print(f"Train samples: {len(train_ds)}, Val samples: {len(val_ds)}, Test samples: {len(test_ds)}")
    
    train_loader = DataLoader(
        train_ds,
        config['batch_size'],
        shuffle=True,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=config['colloc_ratio'],
            M_max=config['M_max'],
            tau_max=config['tau_max'],
            points_per_u=config['points_per_u']
        )
    )
    
    val_loader = DataLoader(
        val_ds,
        config['batch_size'] * 2,
        shuffle=False,
        collate_fn=create_pinn_collate_fn(
            colloc_ratio=0.0,
            M_max=config['M_max'],
            tau_max=config['tau_max']
        )
    )

    test_loader = DataLoader(
        test_ds, config['batch_size'] * 2, shuffle=False,
        collate_fn=create_pinn_collate_fn(colloc_ratio=0.0, M_max=config['M_max'], tau_max=config['tau_max'])
    )
    
    print(f"Train batches: {len(train_loader)}, Val batches: {len(val_loader)}")
    
    # Model (Now using FNO_DeepONet implicitly via DeepBS_Solver changes)
    model = DeepBS_Solver(config['hidden_dim'], config['num_layers'], config['p_dim']).to(device)
    print(f"FNO-DeepONet Model initialized with hidden_dim={config['hidden_dim']}, num_layers={config['num_layers']}, p_dim={config['p_dim']}")
    
    # ==========================================
    # OPTIMIZER SETTINGS
    # ==========================================
    base_lr = config['lr']
    
    optimizer_adam = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': base_lr, 'weight_decay': 1e-4},
        {'params': model.nn1.trunk.parameters(), 'lr': base_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': base_lr},
        {'params': model.nn2.parameters(), 'lr': base_lr, 'weight_decay': 1e-5}
    ])

    #changed
    scheduler = ReduceLROnPlateau(optimizer_adam, 'min', factor=0.5, patience=2)
    
    best_val = float('inf')
    all_train_losses = []
    all_val_losses = []
    
    def evaluate_validation():
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
                _, v_hat = model(M, tau, u, r, q)
                val_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
        val_loss /= len(val_ds)
        model.train()
        return val_loss
    
    # ==========================================
    # STAGE 1: ADAM TRAINING
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 1: Adam Optimizer (FNO Parameter Groups)")
    print("="*60)
    
    epochs_no_improve = 0
    phase1_epochs_completed = 0
    
    for epoch in range(config['epochs_adam']):
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_adam.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_adam.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        scheduler.step(val_loss)
        current_lr = optimizer_adam.param_groups[0]['lr'] 
        
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        phase1_epochs_completed += 1
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), f'best_model_phase1.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nAdam Epoch {epoch+1}/{config['epochs_adam']} | Time: {epoch_time:.1f}s | Base LR: {current_lr:.2e}")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print(f"  Components - Data: {loss_components['data']:.4f} | PDE: {loss_components['pde']:.4f} | Arb: {loss_components['arb']:.4f}")
        print(f"  Epochs without improvement: {epochs_no_improve}/{config['patience_adam']}")
        print("-" * 60)
        
        if epochs_no_improve >= config['patience_adam']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break
            
        torch.cuda.empty_cache()
    
    print(f"\n*** Adam Phase Complete. Best Val MSE: {best_val:.6f} ***")
    
    print("Loading best model from Adam phase for fine-tuning...")
    model.load_state_dict(torch.load('best_model_phase1.pth'))

    #changed
    torch.save(model.state_dict(), f'best_model.pth')
    
    # ==========================================
    # STAGE 2: FINE-TUNING WITH LOW LR ADAM
    # ==========================================
    print("\n" + "="*60)
    print("PHASE 2: Fine-tuning with Adam (Low LR)")
    print("="*60)

    finetune_lr = 1e-5
    optimizer_finetune = optim.Adam([
        {'params': model.nn1.branch.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-5},
        {'params': model.nn1.trunk.parameters(), 'lr': finetune_lr * 0.1, 'weight_decay': 0.0},
        {'params': [model.nn1.bias], 'lr': finetune_lr},
        {'params': model.nn2.parameters(), 'lr': finetune_lr, 'weight_decay': 1e-6}
    ])
    
    epochs_no_improve = 0

    for epoch in range(config['epochs_lbfgs']): 
        model.train()
        epoch_start = time.time()
        total_loss = 0
        loss_components = {'data': 0, 'pde': 0, 'arb': 0, 'term': 0, 'lower': 0, 'upper': 0}
        
        for batch_idx, batch in enumerate(train_loader):
            M, tau, u, r, q, v_true, mask = [b.to(device) for b in batch]
            M = M.clone().requires_grad_(True)
            tau = tau.clone().requires_grad_(True)
            
            optimizer_finetune.zero_grad()
            loss, loss_dict = pinn_loss_fn(
                model, M, tau, u, r, q, v_true, mask,
                lambdas, device,
                num_boundary=config['num_boundary'],
                M_max=config['M_max'],
                tau_max=config['tau_max'],
            )
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), config['grad_clip'])
            optimizer_finetune.step()
            
            total_loss += loss_dict['total']
            for key in loss_components:
                loss_components[key] += loss_dict[key]
            
            if (batch_idx + 1) % 100 == 0:
                print(f"  Epoch {epoch+1} | Batch {batch_idx+1}/{len(train_loader)} | Batch Loss: {loss_dict['total']:.6f}")
        
        val_loss = evaluate_validation()
        epoch_time = time.time() - epoch_start
        avg_loss = total_loss / len(train_loader)
        
        all_train_losses.append(avg_loss)
        all_val_losses.append(val_loss)
        
        for key in loss_components:
            loss_components[key] /= len(train_loader)
        
        improved = ""
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), 'best_model.pth')
            improved = " *** New Best ***"
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        
        print(f"\nFine-tune Epoch {epoch+1}/{config['epochs_lbfgs']} | Time: {epoch_time:.1f}s")
        print(f"  Train Loss: {avg_loss:.6f} | Val MSE: {val_loss:.6f}{improved}")
        print("-" * 60)
        
        torch.cuda.empty_cache()
        
        if epoch >= 10 and epochs_no_improve >= config['patience_lbfgs']:
            print(f"\n*** Early stopping triggered at epoch {epoch+1} ***")
            break

    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print(f"Best Validation MSE: {best_val:.6f}")
    print("="*60)
    
    torch.save(model.state_dict(), 'final_model.pth')
    
    # ==========================================
    # FINAL TEST EVALUATION
    # ==========================================
    print("\n" + "="*60)
    print("RUNNING FINAL TEST SET EVALUATION")
    print("="*60)
    
    model.load_state_dict(torch.load('best_model.pth'))
    model.eval()
    test_loss = 0
    
    with torch.no_grad():
        for batch in test_loader:
            M, tau, u, r, q, v_true, _ = [b.to(device) for b in batch]
            _, v_hat = model(M, tau, u, r, q)
            test_loss += F.mse_loss(v_hat, v_true).item() * M.size(0)
            
    test_loss /= len(test_ds)
    print(f"Final Test MSE: {test_loss:.6f}")
    
    # ==========================================
    # EXPORTING LOGS & PLOTTING
    # ==========================================
    print("\nSaving loss history to 'loss_history.txt'...")
    with open('loss_history.txt', 'w') as f:
        f.write("Epoch\tTrain_Loss\tVal_Loss\n")
        for i, (t_loss, v_loss) in enumerate(zip(all_train_losses, all_val_losses)):
            f.write(f"{i+1}\t{t_loss:.6f}\t{v_loss:.6f}\n")
        f.write(f"\nFinal Test Loss: {test_loss:.6f}\n")

    print("Generating loss curve plot 'loss_plot.png'...")
    plt.figure(figsize=(10, 6))
    plt.plot(all_train_losses, label='Train Loss (Total PINN Loss)')
    plt.plot(all_val_losses, label='Validation Loss (MSE)')
    
    if phase1_epochs_completed < len(all_train_losses):
        plt.axvline(x=phase1_epochs_completed - 1, color='r', linestyle='--', label='Start Phase 2 (Fine-tuning)')
        
    plt.yscale('log')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training & Validation Loss (Test MSE: {test_loss:.6f})')
    plt.legend()
    plt.grid(True, which="both", ls="--", alpha=0.5)
    plt.tight_layout()
    plt.savefig('loss_plot.png')
    plt.close()
    
    print("Execution Finished.")
    
    return model

if __name__ == "__main__":
    train_model()
# Out:
# Device: cuda
# Loading datasets...
# Loaded train: 640582 samples
# Loaded val: 80073 samples
# Loaded test: 80073 samples
# Train samples: 640582, Val samples: 80073, Test samples: 80073
# Train batches: 2503, Val batches: 157
# FNO-DeepONet Model initialized with hidden_dim=64, num_layers=6, p_dim=64
#
# ============================================================
# PHASE 1: Adam Optimizer (FNO Parameter Groups)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 1.407960
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.002870
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.010097
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.001931
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.002669
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.001416
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.003395
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.001676
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.001095
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.009836
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.000850
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.000822
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.577485
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.014112
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.000747
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.000717
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.000937
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.004353
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.009404
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.000731
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.010844
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.001119
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.001043
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.000824
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.001222
#
# Adam Epoch 1/100 | Time: 257.6s | Base LR: 1.00e-03
#   Train Loss: 0.071872 | Val MSE: 0.004029 *** New Best ***
#   Components - Data: 0.0692 | PDE: 0.0045 | Arb: 0.0009
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.001690
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.000571
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.002443
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.001733
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.000869
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.000640
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.002753
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.006109
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.001250
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.034676
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.654581
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.000780
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000709
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.000900
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.000279
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.012549
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.000998
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.000505
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.001116
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.008406
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.000912
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000921
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.001702
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000970
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.000493
#
# Adam Epoch 2/100 | Time: 256.0s | Base LR: 1.00e-03
#   Train Loss: 0.010262 | Val MSE: 0.003291 *** New Best ***
#   Components - Data: 0.0094 | PDE: 0.0015 | Arb: 0.0003
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.001299
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.001346
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.000818
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.004367
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000848
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.004363
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.000588
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000567
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.000534
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.000720
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.007561
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.014984
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.019931
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.002009
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000457
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000587
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.001778
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000227
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.000474
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.003678
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.001009
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000253
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.000604
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000497
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.002386
#
# Adam Epoch 3/100 | Time: 255.6s | Base LR: 1.00e-03
#   Train Loss: 0.007530 | Val MSE: 0.158030
#   Components - Data: 0.0068 | PDE: 0.0013 | Arb: 0.0003
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.000863
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.016921
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.002891
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000362
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.000366
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.000510
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.000622
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.009240
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.000656
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000509
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.001032
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.047906
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.001677
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.010020
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000340
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.001002
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.000696
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.000199
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.002140
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000534
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.000467
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000427
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000804
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.003020
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.000667
#
# Adam Epoch 4/100 | Time: 258.2s | Base LR: 1.00e-03
#   Train Loss: 0.005312 | Val MSE: 0.004369
#   Components - Data: 0.0046 | PDE: 0.0012 | Arb: 0.0002
#   Epochs without improvement: 2/3
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.000875
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000211
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000660
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.001931
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.000369
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000430
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000341
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.009405
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.000573
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000299
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.007894
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000169
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000594
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.001261
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000721
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.000163
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.009665
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.000252
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.012962
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.001421
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000624
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.000351
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000231
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.000424
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.000227
#
# Adam Epoch 5/100 | Time: 255.3s | Base LR: 1.00e-03
#   Train Loss: 0.003640 | Val MSE: 0.002566 *** New Best ***
#   Components - Data: 0.0031 | PDE: 0.0010 | Arb: 0.0002
#   Epochs without improvement: 0/3
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000636
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.021363
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000416
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.001068
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.000343
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.004404
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000620
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.000689
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000526
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.002181
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000881
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.016299
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.008296
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.000542
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.004807
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000973
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000606
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.001420
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000225
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000330
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.000234
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000824
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.005398
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.000185
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.004771
#
# Adam Epoch 6/100 | Time: 254.0s | Base LR: 1.00e-03
#   Train Loss: 0.004281 | Val MSE: 0.003859
#   Components - Data: 0.0037 | PDE: 0.0010 | Arb: 0.0002
#   Epochs without improvement: 1/3
# ------------------------------------------------------------
#   Epoch 7 | Batch 100/2503 | Batch Loss: 0.008055
#   Epoch 7 | Batch 200/2503 | Batch Loss: 0.013582
#   Epoch 7 | Batch 300/2503 | Batch Loss: 0.000211
#   Epoch 7 | Batch 400/2503 | Batch Loss: 0.000547
#   Epoch 7 | Batch 500/2503 | Batch Loss: 0.004808
#   Epoch 7 | Batch 600/2503 | Batch Loss: 0.001502
#   Epoch 7 | Batch 700/2503 | Batch Loss: 0.000675
#   Epoch 7 | Batch 800/2503 | Batch Loss: 0.000222
#   Epoch 7 | Batch 900/2503 | Batch Loss: 0.004044
#   Epoch 7 | Batch 1000/2503 | Batch Loss: 0.000203
#   Epoch 7 | Batch 1100/2503 | Batch Loss: 0.001874
#   Epoch 7 | Batch 1200/2503 | Batch Loss: 0.000717
#   Epoch 7 | Batch 1300/2503 | Batch Loss: 0.000233
#   Epoch 7 | Batch 1400/2503 | Batch Loss: 0.013625
#   Epoch 7 | Batch 1500/2503 | Batch Loss: 0.000181
#   Epoch 7 | Batch 1600/2503 | Batch Loss: 0.001493
#   Epoch 7 | Batch 1700/2503 | Batch Loss: 0.000491
#   Epoch 7 | Batch 1800/2503 | Batch Loss: 0.000290
#   Epoch 7 | Batch 1900/2503 | Batch Loss: 0.001349
#   Epoch 7 | Batch 2000/2503 | Batch Loss: 0.003449
#   Epoch 7 | Batch 2100/2503 | Batch Loss: 0.000434
#   Epoch 7 | Batch 2200/2503 | Batch Loss: 0.000421
#   Epoch 7 | Batch 2300/2503 | Batch Loss: 0.000267
#   Epoch 7 | Batch 2400/2503 | Batch Loss: 0.000395
#   Epoch 7 | Batch 2500/2503 | Batch Loss: 0.008112
#
# Adam Epoch 7/100 | Time: 254.3s | Base LR: 1.00e-03
#   Train Loss: 0.003120 | Val MSE: 0.006736
#   Components - Data: 0.0025 | PDE: 0.0010 | Arb: 0.0002
#   Epochs without improvement: 2/3
# ------------------------------------------------------------
#   Epoch 8 | Batch 100/2503 | Batch Loss: 0.001006
#   Epoch 8 | Batch 200/2503 | Batch Loss: 0.016444
#   Epoch 8 | Batch 300/2503 | Batch Loss: 0.000450
#   Epoch 8 | Batch 400/2503 | Batch Loss: 0.000280
#   Epoch 8 | Batch 500/2503 | Batch Loss: 0.008204
#   Epoch 8 | Batch 600/2503 | Batch Loss: 0.003550
#   Epoch 8 | Batch 700/2503 | Batch Loss: 0.000581
#   Epoch 8 | Batch 800/2503 | Batch Loss: 0.000542
#   Epoch 8 | Batch 900/2503 | Batch Loss: 0.000382
#   Epoch 8 | Batch 1000/2503 | Batch Loss: 0.000613
#   Epoch 8 | Batch 1100/2503 | Batch Loss: 0.000158
#   Epoch 8 | Batch 1200/2503 | Batch Loss: 0.000375
#   Epoch 8 | Batch 1300/2503 | Batch Loss: 0.000625
#   Epoch 8 | Batch 1400/2503 | Batch Loss: 0.000147
#   Epoch 8 | Batch 1500/2503 | Batch Loss: 0.000736
#   Epoch 8 | Batch 1600/2503 | Batch Loss: 0.000239
#   Epoch 8 | Batch 1700/2503 | Batch Loss: 0.000252
#   Epoch 8 | Batch 1800/2503 | Batch Loss: 0.000358
#   Epoch 8 | Batch 1900/2503 | Batch Loss: 0.000516
#   Epoch 8 | Batch 2000/2503 | Batch Loss: 0.000408
#   Epoch 8 | Batch 2100/2503 | Batch Loss: 0.000166
#   Epoch 8 | Batch 2200/2503 | Batch Loss: 0.013245
#   Epoch 8 | Batch 2300/2503 | Batch Loss: 0.000208
#   Epoch 8 | Batch 2400/2503 | Batch Loss: 0.000796
#   Epoch 8 | Batch 2500/2503 | Batch Loss: 0.000469
#
# Adam Epoch 8/100 | Time: 253.2s | Base LR: 5.00e-04
#   Train Loss: 0.002633 | Val MSE: 0.002715
#   Components - Data: 0.0021 | PDE: 0.0010 | Arb: 0.0002
#   Epochs without improvement: 3/3
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 8 ***
#
# *** Adam Phase Complete. Best Val MSE: 0.002566 ***
# Loading best model from Adam phase for fine-tuning...
#
# ============================================================
# PHASE 2: Fine-tuning with Adam (Low LR)
# ============================================================
#   Epoch 1 | Batch 100/2503 | Batch Loss: 0.000163
#   Epoch 1 | Batch 200/2503 | Batch Loss: 0.000157
#   Epoch 1 | Batch 300/2503 | Batch Loss: 0.000165
#   Epoch 1 | Batch 400/2503 | Batch Loss: 0.001731
#   Epoch 1 | Batch 500/2503 | Batch Loss: 0.000136
#   Epoch 1 | Batch 600/2503 | Batch Loss: 0.000299
#   Epoch 1 | Batch 700/2503 | Batch Loss: 0.000146
#   Epoch 1 | Batch 800/2503 | Batch Loss: 0.000298
#   Epoch 1 | Batch 900/2503 | Batch Loss: 0.000240
#   Epoch 1 | Batch 1000/2503 | Batch Loss: 0.000834
#   Epoch 1 | Batch 1100/2503 | Batch Loss: 0.000158
#   Epoch 1 | Batch 1200/2503 | Batch Loss: 0.000160
#   Epoch 1 | Batch 1300/2503 | Batch Loss: 0.000237
#   Epoch 1 | Batch 1400/2503 | Batch Loss: 0.000161
#   Epoch 1 | Batch 1500/2503 | Batch Loss: 0.007444
#   Epoch 1 | Batch 1600/2503 | Batch Loss: 0.000133
#   Epoch 1 | Batch 1700/2503 | Batch Loss: 0.000164
#   Epoch 1 | Batch 1800/2503 | Batch Loss: 0.000733
#   Epoch 1 | Batch 1900/2503 | Batch Loss: 0.000137
#   Epoch 1 | Batch 2000/2503 | Batch Loss: 0.000134
#   Epoch 1 | Batch 2100/2503 | Batch Loss: 0.000122
#   Epoch 1 | Batch 2200/2503 | Batch Loss: 0.003103
#   Epoch 1 | Batch 2300/2503 | Batch Loss: 0.000119
#   Epoch 1 | Batch 2400/2503 | Batch Loss: 0.000135
#   Epoch 1 | Batch 2500/2503 | Batch Loss: 0.000188
#
# Fine-tune Epoch 1/50 | Time: 252.4s
#   Train Loss: 0.001375 | Val MSE: 0.003052
# ------------------------------------------------------------
#   Epoch 2 | Batch 100/2503 | Batch Loss: 0.000143
#   Epoch 2 | Batch 200/2503 | Batch Loss: 0.000129
#   Epoch 2 | Batch 300/2503 | Batch Loss: 0.000210
#   Epoch 2 | Batch 400/2503 | Batch Loss: 0.000128
#   Epoch 2 | Batch 500/2503 | Batch Loss: 0.000115
#   Epoch 2 | Batch 600/2503 | Batch Loss: 0.000155
#   Epoch 2 | Batch 700/2503 | Batch Loss: 0.000202
#   Epoch 2 | Batch 800/2503 | Batch Loss: 0.000128
#   Epoch 2 | Batch 900/2503 | Batch Loss: 0.009653
#   Epoch 2 | Batch 1000/2503 | Batch Loss: 0.000514
#   Epoch 2 | Batch 1100/2503 | Batch Loss: 0.000114
#   Epoch 2 | Batch 1200/2503 | Batch Loss: 0.000163
#   Epoch 2 | Batch 1300/2503 | Batch Loss: 0.000135
#   Epoch 2 | Batch 1400/2503 | Batch Loss: 0.000147
#   Epoch 2 | Batch 1500/2503 | Batch Loss: 0.000156
#   Epoch 2 | Batch 1600/2503 | Batch Loss: 0.000153
#   Epoch 2 | Batch 1700/2503 | Batch Loss: 0.000125
#   Epoch 2 | Batch 1800/2503 | Batch Loss: 0.000156
#   Epoch 2 | Batch 1900/2503 | Batch Loss: 0.000327
#   Epoch 2 | Batch 2000/2503 | Batch Loss: 0.000116
#   Epoch 2 | Batch 2100/2503 | Batch Loss: 0.001149
#   Epoch 2 | Batch 2200/2503 | Batch Loss: 0.000111
#   Epoch 2 | Batch 2300/2503 | Batch Loss: 0.000180
#   Epoch 2 | Batch 2400/2503 | Batch Loss: 0.000184
#   Epoch 2 | Batch 2500/2503 | Batch Loss: 0.003530
#
# Fine-tune Epoch 2/50 | Time: 257.5s
#   Train Loss: 0.001001 | Val MSE: 0.002244 *** New Best ***
# ------------------------------------------------------------
#   Epoch 3 | Batch 100/2503 | Batch Loss: 0.000667
#   Epoch 3 | Batch 200/2503 | Batch Loss: 0.000122
#   Epoch 3 | Batch 300/2503 | Batch Loss: 0.001770
#   Epoch 3 | Batch 400/2503 | Batch Loss: 0.000145
#   Epoch 3 | Batch 500/2503 | Batch Loss: 0.000723
#   Epoch 3 | Batch 600/2503 | Batch Loss: 0.001223
#   Epoch 3 | Batch 700/2503 | Batch Loss: 0.006059
#   Epoch 3 | Batch 800/2503 | Batch Loss: 0.000150
#   Epoch 3 | Batch 900/2503 | Batch Loss: 0.000142
#   Epoch 3 | Batch 1000/2503 | Batch Loss: 0.000207
#   Epoch 3 | Batch 1100/2503 | Batch Loss: 0.000125
#   Epoch 3 | Batch 1200/2503 | Batch Loss: 0.000118
#   Epoch 3 | Batch 1300/2503 | Batch Loss: 0.001768
#   Epoch 3 | Batch 1400/2503 | Batch Loss: 0.000121
#   Epoch 3 | Batch 1500/2503 | Batch Loss: 0.000113
#   Epoch 3 | Batch 1600/2503 | Batch Loss: 0.000121
#   Epoch 3 | Batch 1700/2503 | Batch Loss: 0.000117
#   Epoch 3 | Batch 1800/2503 | Batch Loss: 0.000099
#   Epoch 3 | Batch 1900/2503 | Batch Loss: 0.000120
#   Epoch 3 | Batch 2000/2503 | Batch Loss: 0.000469
#   Epoch 3 | Batch 2100/2503 | Batch Loss: 0.004562
#   Epoch 3 | Batch 2200/2503 | Batch Loss: 0.000113
#   Epoch 3 | Batch 2300/2503 | Batch Loss: 0.000101
#   Epoch 3 | Batch 2400/2503 | Batch Loss: 0.000118
#   Epoch 3 | Batch 2500/2503 | Batch Loss: 0.001929
#
# Fine-tune Epoch 3/50 | Time: 257.8s
#   Train Loss: 0.000831 | Val MSE: 0.002058 *** New Best ***
# ------------------------------------------------------------
#   Epoch 4 | Batch 100/2503 | Batch Loss: 0.000109
#   Epoch 4 | Batch 200/2503 | Batch Loss: 0.000132
#   Epoch 4 | Batch 300/2503 | Batch Loss: 0.000118
#   Epoch 4 | Batch 400/2503 | Batch Loss: 0.000154
#   Epoch 4 | Batch 500/2503 | Batch Loss: 0.000123
#   Epoch 4 | Batch 600/2503 | Batch Loss: 0.000317
#   Epoch 4 | Batch 700/2503 | Batch Loss: 0.000117
#   Epoch 4 | Batch 800/2503 | Batch Loss: 0.000525
#   Epoch 4 | Batch 900/2503 | Batch Loss: 0.000108
#   Epoch 4 | Batch 1000/2503 | Batch Loss: 0.000109
#   Epoch 4 | Batch 1100/2503 | Batch Loss: 0.000122
#   Epoch 4 | Batch 1200/2503 | Batch Loss: 0.000122
#   Epoch 4 | Batch 1300/2503 | Batch Loss: 0.000123
#   Epoch 4 | Batch 1400/2503 | Batch Loss: 0.000103
#   Epoch 4 | Batch 1500/2503 | Batch Loss: 0.000118
#   Epoch 4 | Batch 1600/2503 | Batch Loss: 0.000100
#   Epoch 4 | Batch 1700/2503 | Batch Loss: 0.001259
#   Epoch 4 | Batch 1800/2503 | Batch Loss: 0.001631
#   Epoch 4 | Batch 1900/2503 | Batch Loss: 0.000097
#   Epoch 4 | Batch 2000/2503 | Batch Loss: 0.000117
#   Epoch 4 | Batch 2100/2503 | Batch Loss: 0.000112
#   Epoch 4 | Batch 2200/2503 | Batch Loss: 0.000103
#   Epoch 4 | Batch 2300/2503 | Batch Loss: 0.000472
#   Epoch 4 | Batch 2400/2503 | Batch Loss: 0.000125
#   Epoch 4 | Batch 2500/2503 | Batch Loss: 0.000140
#
# Fine-tune Epoch 4/50 | Time: 259.5s
#   Train Loss: 0.000716 | Val MSE: 0.002054 *** New Best ***
# ------------------------------------------------------------
#   Epoch 5 | Batch 100/2503 | Batch Loss: 0.000099
#   Epoch 5 | Batch 200/2503 | Batch Loss: 0.000306
#   Epoch 5 | Batch 300/2503 | Batch Loss: 0.000122
#   Epoch 5 | Batch 400/2503 | Batch Loss: 0.000101
#   Epoch 5 | Batch 500/2503 | Batch Loss: 0.000111
#   Epoch 5 | Batch 600/2503 | Batch Loss: 0.000101
#   Epoch 5 | Batch 700/2503 | Batch Loss: 0.000104
#   Epoch 5 | Batch 800/2503 | Batch Loss: 0.000104
#   Epoch 5 | Batch 900/2503 | Batch Loss: 0.000363
#   Epoch 5 | Batch 1000/2503 | Batch Loss: 0.000113
#   Epoch 5 | Batch 1100/2503 | Batch Loss: 0.000121
#   Epoch 5 | Batch 1200/2503 | Batch Loss: 0.000137
#   Epoch 5 | Batch 1300/2503 | Batch Loss: 0.000165
#   Epoch 5 | Batch 1400/2503 | Batch Loss: 0.000100
#   Epoch 5 | Batch 1500/2503 | Batch Loss: 0.000333
#   Epoch 5 | Batch 1600/2503 | Batch Loss: 0.002860
#   Epoch 5 | Batch 1700/2503 | Batch Loss: 0.000093
#   Epoch 5 | Batch 1800/2503 | Batch Loss: 0.000098
#   Epoch 5 | Batch 1900/2503 | Batch Loss: 0.000097
#   Epoch 5 | Batch 2000/2503 | Batch Loss: 0.000094
#   Epoch 5 | Batch 2100/2503 | Batch Loss: 0.000111
#   Epoch 5 | Batch 2200/2503 | Batch Loss: 0.000097
#   Epoch 5 | Batch 2300/2503 | Batch Loss: 0.000147
#   Epoch 5 | Batch 2400/2503 | Batch Loss: 0.000100
#   Epoch 5 | Batch 2500/2503 | Batch Loss: 0.000115
#
# Fine-tune Epoch 5/50 | Time: 253.3s
#   Train Loss: 0.000631 | Val MSE: 0.001644 *** New Best ***
# ------------------------------------------------------------
#   Epoch 6 | Batch 100/2503 | Batch Loss: 0.000120
#   Epoch 6 | Batch 200/2503 | Batch Loss: 0.000096
#   Epoch 6 | Batch 300/2503 | Batch Loss: 0.000111
#   Epoch 6 | Batch 400/2503 | Batch Loss: 0.000118
#   Epoch 6 | Batch 500/2503 | Batch Loss: 0.000105
#   Epoch 6 | Batch 600/2503 | Batch Loss: 0.000109
#   Epoch 6 | Batch 700/2503 | Batch Loss: 0.000136
#   Epoch 6 | Batch 800/2503 | Batch Loss: 0.001205
#   Epoch 6 | Batch 900/2503 | Batch Loss: 0.000120
#   Epoch 6 | Batch 1000/2503 | Batch Loss: 0.001519
#   Epoch 6 | Batch 1100/2503 | Batch Loss: 0.000100
#   Epoch 6 | Batch 1200/2503 | Batch Loss: 0.000162
#   Epoch 6 | Batch 1300/2503 | Batch Loss: 0.000099
#   Epoch 6 | Batch 1400/2503 | Batch Loss: 0.000114
#   Epoch 6 | Batch 1500/2503 | Batch Loss: 0.000091
#   Epoch 6 | Batch 1600/2503 | Batch Loss: 0.000105
#   Epoch 6 | Batch 1700/2503 | Batch Loss: 0.000125
#   Epoch 6 | Batch 1800/2503 | Batch Loss: 0.000104
#   Epoch 6 | Batch 1900/2503 | Batch Loss: 0.000120
#   Epoch 6 | Batch 2000/2503 | Batch Loss: 0.000136
#   Epoch 6 | Batch 2100/2503 | Batch Loss: 0.003748
#   Epoch 6 | Batch 2200/2503 | Batch Loss: 0.000113
#   Epoch 6 | Batch 2300/2503 | Batch Loss: 0.000101
#   Epoch 6 | Batch 2400/2503 | Batch Loss: 0.001528
#   Epoch 6 | Batch 2500/2503 | Batch Loss: 0.000107
#
# Fine-tune Epoch 6/50 | Time: 249.9s
#   Train Loss: 0.000555 | Val MSE: 0.001161 *** New Best ***
# ------------------------------------------------------------
#   Epoch 7 | Batch 100/2503 | Batch Loss: 0.000441
#   Epoch 7 | Batch 200/2503 | Batch Loss: 0.000094
#   Epoch 7 | Batch 300/2503 | Batch Loss: 0.000106
#   Epoch 7 | Batch 400/2503 | Batch Loss: 0.001958
#   Epoch 7 | Batch 500/2503 | Batch Loss: 0.000101
#   Epoch 7 | Batch 600/2503 | Batch Loss: 0.000093
#   Epoch 7 | Batch 700/2503 | Batch Loss: 0.000106
#   Epoch 7 | Batch 800/2503 | Batch Loss: 0.000499
#   Epoch 7 | Batch 900/2503 | Batch Loss: 0.000100
#   Epoch 7 | Batch 1000/2503 | Batch Loss: 0.000124
#   Epoch 7 | Batch 1100/2503 | Batch Loss: 0.000854
#   Epoch 7 | Batch 1200/2503 | Batch Loss: 0.000423
#   Epoch 7 | Batch 1300/2503 | Batch Loss: 0.000109
#   Epoch 7 | Batch 1400/2503 | Batch Loss: 0.000110
#   Epoch 7 | Batch 1500/2503 | Batch Loss: 0.000140
#   Epoch 7 | Batch 1600/2503 | Batch Loss: 0.000113
#   Epoch 7 | Batch 1700/2503 | Batch Loss: 0.000792
#   Epoch 7 | Batch 1800/2503 | Batch Loss: 0.000117
#   Epoch 7 | Batch 1900/2503 | Batch Loss: 0.000105
#   Epoch 7 | Batch 2000/2503 | Batch Loss: 0.000119
#   Epoch 7 | Batch 2100/2503 | Batch Loss: 0.001175
#   Epoch 7 | Batch 2200/2503 | Batch Loss: 0.000132
#   Epoch 7 | Batch 2300/2503 | Batch Loss: 0.000936
#   Epoch 7 | Batch 2400/2503 | Batch Loss: 0.000114
#   Epoch 7 | Batch 2500/2503 | Batch Loss: 0.000111
#
# Fine-tune Epoch 7/50 | Time: 250.0s
#   Train Loss: 0.000511 | Val MSE: 0.001353
# ------------------------------------------------------------
#   Epoch 8 | Batch 100/2503 | Batch Loss: 0.000097
#   Epoch 8 | Batch 200/2503 | Batch Loss: 0.000100
#   Epoch 8 | Batch 300/2503 | Batch Loss: 0.002462
#   Epoch 8 | Batch 400/2503 | Batch Loss: 0.000102
#   Epoch 8 | Batch 500/2503 | Batch Loss: 0.000113
#   Epoch 8 | Batch 600/2503 | Batch Loss: 0.000218
#   Epoch 8 | Batch 700/2503 | Batch Loss: 0.000092
#   Epoch 8 | Batch 800/2503 | Batch Loss: 0.000101
#   Epoch 8 | Batch 900/2503 | Batch Loss: 0.000090
#   Epoch 8 | Batch 1000/2503 | Batch Loss: 0.000971
#   Epoch 8 | Batch 1100/2503 | Batch Loss: 0.002201
#   Epoch 8 | Batch 1200/2503 | Batch Loss: 0.000099
#   Epoch 8 | Batch 1300/2503 | Batch Loss: 0.000104
#   Epoch 8 | Batch 1400/2503 | Batch Loss: 0.000096
#   Epoch 8 | Batch 1500/2503 | Batch Loss: 0.000104
#   Epoch 8 | Batch 1600/2503 | Batch Loss: 0.000102
#   Epoch 8 | Batch 1700/2503 | Batch Loss: 0.000130
#   Epoch 8 | Batch 1800/2503 | Batch Loss: 0.000100
#   Epoch 8 | Batch 1900/2503 | Batch Loss: 0.000094
#   Epoch 8 | Batch 2000/2503 | Batch Loss: 0.000098
#   Epoch 8 | Batch 2100/2503 | Batch Loss: 0.000186
#   Epoch 8 | Batch 2200/2503 | Batch Loss: 0.000094
#   Epoch 8 | Batch 2300/2503 | Batch Loss: 0.000975
#   Epoch 8 | Batch 2400/2503 | Batch Loss: 0.000094
#   Epoch 8 | Batch 2500/2503 | Batch Loss: 0.000102
#
# Fine-tune Epoch 8/50 | Time: 257.9s
#   Train Loss: 0.000450 | Val MSE: 0.001124 *** New Best ***
# ------------------------------------------------------------
#   Epoch 9 | Batch 100/2503 | Batch Loss: 0.000131
#   Epoch 9 | Batch 200/2503 | Batch Loss: 0.000095
#   Epoch 9 | Batch 300/2503 | Batch Loss: 0.000084
#   Epoch 9 | Batch 400/2503 | Batch Loss: 0.000101
#   Epoch 9 | Batch 500/2503 | Batch Loss: 0.000099
#   Epoch 9 | Batch 600/2503 | Batch Loss: 0.000101
#   Epoch 9 | Batch 700/2503 | Batch Loss: 0.000461
#   Epoch 9 | Batch 800/2503 | Batch Loss: 0.000108
#   Epoch 9 | Batch 900/2503 | Batch Loss: 0.000114
#   Epoch 9 | Batch 1000/2503 | Batch Loss: 0.000098
#   Epoch 9 | Batch 1100/2503 | Batch Loss: 0.000108
#   Epoch 9 | Batch 1200/2503 | Batch Loss: 0.003928
#   Epoch 9 | Batch 1300/2503 | Batch Loss: 0.001614
#   Epoch 9 | Batch 1400/2503 | Batch Loss: 0.000230
#   Epoch 9 | Batch 1500/2503 | Batch Loss: 0.001142
#   Epoch 9 | Batch 1600/2503 | Batch Loss: 0.000622
#   Epoch 9 | Batch 1700/2503 | Batch Loss: 0.000095
#   Epoch 9 | Batch 1800/2503 | Batch Loss: 0.000109
#   Epoch 9 | Batch 1900/2503 | Batch Loss: 0.000117
#   Epoch 9 | Batch 2000/2503 | Batch Loss: 0.000091
#   Epoch 9 | Batch 2100/2503 | Batch Loss: 0.000412
#   Epoch 9 | Batch 2200/2503 | Batch Loss: 0.001260
#   Epoch 9 | Batch 2300/2503 | Batch Loss: 0.000979
#   Epoch 9 | Batch 2400/2503 | Batch Loss: 0.000083
#   Epoch 9 | Batch 2500/2503 | Batch Loss: 0.000086
#
# Fine-tune Epoch 9/50 | Time: 258.4s
#   Train Loss: 0.000411 | Val MSE: 0.000874 *** New Best ***
# ------------------------------------------------------------
#   Epoch 10 | Batch 100/2503 | Batch Loss: 0.000090
#   Epoch 10 | Batch 200/2503 | Batch Loss: 0.002169
#   Epoch 10 | Batch 300/2503 | Batch Loss: 0.000096
#   Epoch 10 | Batch 400/2503 | Batch Loss: 0.000114
#   Epoch 10 | Batch 500/2503 | Batch Loss: 0.000089
#   Epoch 10 | Batch 600/2503 | Batch Loss: 0.000109
#   Epoch 10 | Batch 700/2503 | Batch Loss: 0.000103
#   Epoch 10 | Batch 800/2503 | Batch Loss: 0.000121
#   Epoch 10 | Batch 900/2503 | Batch Loss: 0.000100
#   Epoch 10 | Batch 1000/2503 | Batch Loss: 0.000105
#   Epoch 10 | Batch 1100/2503 | Batch Loss: 0.000756
#   Epoch 10 | Batch 1200/2503 | Batch Loss: 0.001267
#   Epoch 10 | Batch 1300/2503 | Batch Loss: 0.000092
#   Epoch 10 | Batch 1400/2503 | Batch Loss: 0.002045
#   Epoch 10 | Batch 1500/2503 | Batch Loss: 0.000103
#   Epoch 10 | Batch 1600/2503 | Batch Loss: 0.000105
#   Epoch 10 | Batch 1700/2503 | Batch Loss: 0.000174
#   Epoch 10 | Batch 1800/2503 | Batch Loss: 0.001665
#   Epoch 10 | Batch 1900/2503 | Batch Loss: 0.000103
#   Epoch 10 | Batch 2000/2503 | Batch Loss: 0.000090
#   Epoch 10 | Batch 2100/2503 | Batch Loss: 0.000109
#   Epoch 10 | Batch 2200/2503 | Batch Loss: 0.000113
#   Epoch 10 | Batch 2300/2503 | Batch Loss: 0.000080
#   Epoch 10 | Batch 2400/2503 | Batch Loss: 0.000086
#   Epoch 10 | Batch 2500/2503 | Batch Loss: 0.000102
#
# Fine-tune Epoch 10/50 | Time: 258.1s
#   Train Loss: 0.000378 | Val MSE: 0.000748 *** New Best ***
# ------------------------------------------------------------
#   Epoch 11 | Batch 100/2503 | Batch Loss: 0.000086
#   Epoch 11 | Batch 200/2503 | Batch Loss: 0.001248
#   Epoch 11 | Batch 300/2503 | Batch Loss: 0.002197
#   Epoch 11 | Batch 400/2503 | Batch Loss: 0.000183
#   Epoch 11 | Batch 500/2503 | Batch Loss: 0.000107
#   Epoch 11 | Batch 600/2503 | Batch Loss: 0.000133
#   Epoch 11 | Batch 700/2503 | Batch Loss: 0.000604
#   Epoch 11 | Batch 800/2503 | Batch Loss: 0.000115
#   Epoch 11 | Batch 900/2503 | Batch Loss: 0.000120
#   Epoch 11 | Batch 1000/2503 | Batch Loss: 0.000120
#   Epoch 11 | Batch 1100/2503 | Batch Loss: 0.000090
#   Epoch 11 | Batch 1200/2503 | Batch Loss: 0.002778
#   Epoch 11 | Batch 1300/2503 | Batch Loss: 0.000096
#   Epoch 11 | Batch 1400/2503 | Batch Loss: 0.000108
#   Epoch 11 | Batch 1500/2503 | Batch Loss: 0.001594
#   Epoch 11 | Batch 1600/2503 | Batch Loss: 0.000163
#   Epoch 11 | Batch 1700/2503 | Batch Loss: 0.000688
#   Epoch 11 | Batch 1800/2503 | Batch Loss: 0.000079
#   Epoch 11 | Batch 1900/2503 | Batch Loss: 0.000102
#   Epoch 11 | Batch 2000/2503 | Batch Loss: 0.000092
#   Epoch 11 | Batch 2100/2503 | Batch Loss: 0.001148
#   Epoch 11 | Batch 2200/2503 | Batch Loss: 0.000104
#   Epoch 11 | Batch 2300/2503 | Batch Loss: 0.000088
#   Epoch 11 | Batch 2400/2503 | Batch Loss: 0.000109
#   Epoch 11 | Batch 2500/2503 | Batch Loss: 0.000103
#
# Fine-tune Epoch 11/50 | Time: 258.8s
#   Train Loss: 0.000347 | Val MSE: 0.000729 *** New Best ***
# ------------------------------------------------------------
#   Epoch 12 | Batch 100/2503 | Batch Loss: 0.000134
#   Epoch 12 | Batch 200/2503 | Batch Loss: 0.000103
#   Epoch 12 | Batch 300/2503 | Batch Loss: 0.000100
#   Epoch 12 | Batch 400/2503 | Batch Loss: 0.000114
#   Epoch 12 | Batch 500/2503 | Batch Loss: 0.000099
#   Epoch 12 | Batch 600/2503 | Batch Loss: 0.000749
#   Epoch 12 | Batch 700/2503 | Batch Loss: 0.000085
#   Epoch 12 | Batch 800/2503 | Batch Loss: 0.000092
#   Epoch 12 | Batch 900/2503 | Batch Loss: 0.000787
#   Epoch 12 | Batch 1000/2503 | Batch Loss: 0.000081
#   Epoch 12 | Batch 1100/2503 | Batch Loss: 0.000082
#   Epoch 12 | Batch 1200/2503 | Batch Loss: 0.000121
#   Epoch 12 | Batch 1300/2503 | Batch Loss: 0.000089
#   Epoch 12 | Batch 1400/2503 | Batch Loss: 0.000098
#   Epoch 12 | Batch 1500/2503 | Batch Loss: 0.000107
#   Epoch 12 | Batch 1600/2503 | Batch Loss: 0.000096
#   Epoch 12 | Batch 1700/2503 | Batch Loss: 0.000889
#   Epoch 12 | Batch 1800/2503 | Batch Loss: 0.001058
#   Epoch 12 | Batch 1900/2503 | Batch Loss: 0.001079
#   Epoch 12 | Batch 2000/2503 | Batch Loss: 0.000115
#   Epoch 12 | Batch 2100/2503 | Batch Loss: 0.000920
#   Epoch 12 | Batch 2200/2503 | Batch Loss: 0.000124
#   Epoch 12 | Batch 2300/2503 | Batch Loss: 0.001263
#   Epoch 12 | Batch 2400/2503 | Batch Loss: 0.000135
#   Epoch 12 | Batch 2500/2503 | Batch Loss: 0.000147
#
# Fine-tune Epoch 12/50 | Time: 258.3s
#   Train Loss: 0.000324 | Val MSE: 0.000589 *** New Best ***
# ------------------------------------------------------------
#   Epoch 13 | Batch 100/2503 | Batch Loss: 0.000099
#   Epoch 13 | Batch 200/2503 | Batch Loss: 0.000105
#   Epoch 13 | Batch 300/2503 | Batch Loss: 0.000216
#   Epoch 13 | Batch 400/2503 | Batch Loss: 0.000969
#   Epoch 13 | Batch 500/2503 | Batch Loss: 0.000094
#   Epoch 13 | Batch 600/2503 | Batch Loss: 0.000122
#   Epoch 13 | Batch 700/2503 | Batch Loss: 0.003320
#   Epoch 13 | Batch 800/2503 | Batch Loss: 0.000090
#   Epoch 13 | Batch 900/2503 | Batch Loss: 0.000092
#   Epoch 13 | Batch 1000/2503 | Batch Loss: 0.000097
#   Epoch 13 | Batch 1100/2503 | Batch Loss: 0.001003
#   Epoch 13 | Batch 1200/2503 | Batch Loss: 0.000100
#   Epoch 13 | Batch 1300/2503 | Batch Loss: 0.000121
#   Epoch 13 | Batch 1400/2503 | Batch Loss: 0.000097
#   Epoch 13 | Batch 1500/2503 | Batch Loss: 0.000089
#   Epoch 13 | Batch 1600/2503 | Batch Loss: 0.000086
#   Epoch 13 | Batch 1700/2503 | Batch Loss: 0.000099
#   Epoch 13 | Batch 1800/2503 | Batch Loss: 0.000126
#   Epoch 13 | Batch 1900/2503 | Batch Loss: 0.000107
#   Epoch 13 | Batch 2000/2503 | Batch Loss: 0.000096
#   Epoch 13 | Batch 2100/2503 | Batch Loss: 0.000893
#   Epoch 13 | Batch 2200/2503 | Batch Loss: 0.000518
#   Epoch 13 | Batch 2300/2503 | Batch Loss: 0.000108
#   Epoch 13 | Batch 2400/2503 | Batch Loss: 0.000097
#   Epoch 13 | Batch 2500/2503 | Batch Loss: 0.002770
#
# Fine-tune Epoch 13/50 | Time: 257.9s
#   Train Loss: 0.000305 | Val MSE: 0.000663
# ------------------------------------------------------------
#   Epoch 14 | Batch 100/2503 | Batch Loss: 0.000111
#   Epoch 14 | Batch 200/2503 | Batch Loss: 0.000095
#   Epoch 14 | Batch 300/2503 | Batch Loss: 0.000517
#   Epoch 14 | Batch 400/2503 | Batch Loss: 0.000135
#   Epoch 14 | Batch 500/2503 | Batch Loss: 0.000111
#   Epoch 14 | Batch 600/2503 | Batch Loss: 0.000083
#   Epoch 14 | Batch 700/2503 | Batch Loss: 0.000101
#   Epoch 14 | Batch 800/2503 | Batch Loss: 0.000115
#   Epoch 14 | Batch 900/2503 | Batch Loss: 0.001869
#   Epoch 14 | Batch 1000/2503 | Batch Loss: 0.000272
#   Epoch 14 | Batch 1100/2503 | Batch Loss: 0.000091
#   Epoch 14 | Batch 1200/2503 | Batch Loss: 0.000090
#   Epoch 14 | Batch 1300/2503 | Batch Loss: 0.000087
#   Epoch 14 | Batch 1400/2503 | Batch Loss: 0.000742
#   Epoch 14 | Batch 1500/2503 | Batch Loss: 0.000098
#   Epoch 14 | Batch 1600/2503 | Batch Loss: 0.000097
#   Epoch 14 | Batch 1700/2503 | Batch Loss: 0.000136
#   Epoch 14 | Batch 1800/2503 | Batch Loss: 0.000093
#   Epoch 14 | Batch 1900/2503 | Batch Loss: 0.000178
#   Epoch 14 | Batch 2000/2503 | Batch Loss: 0.000094
#   Epoch 14 | Batch 2100/2503 | Batch Loss: 0.000103
#   Epoch 14 | Batch 2200/2503 | Batch Loss: 0.000085
#   Epoch 14 | Batch 2300/2503 | Batch Loss: 0.000086
#   Epoch 14 | Batch 2400/2503 | Batch Loss: 0.000956
#   Epoch 14 | Batch 2500/2503 | Batch Loss: 0.000082
#
# Fine-tune Epoch 14/50 | Time: 258.0s
#   Train Loss: 0.000293 | Val MSE: 0.000539 *** New Best ***
# ------------------------------------------------------------
#   Epoch 15 | Batch 100/2503 | Batch Loss: 0.000088
#   Epoch 15 | Batch 200/2503 | Batch Loss: 0.000146
#   Epoch 15 | Batch 300/2503 | Batch Loss: 0.000094
#   Epoch 15 | Batch 400/2503 | Batch Loss: 0.000100
#   Epoch 15 | Batch 500/2503 | Batch Loss: 0.000084
#   Epoch 15 | Batch 600/2503 | Batch Loss: 0.000089
#   Epoch 15 | Batch 700/2503 | Batch Loss: 0.000152
#   Epoch 15 | Batch 800/2503 | Batch Loss: 0.000229
#   Epoch 15 | Batch 900/2503 | Batch Loss: 0.000101
#   Epoch 15 | Batch 1000/2503 | Batch Loss: 0.000088
#   Epoch 15 | Batch 1100/2503 | Batch Loss: 0.000091
#   Epoch 15 | Batch 1200/2503 | Batch Loss: 0.000096
#   Epoch 15 | Batch 1300/2503 | Batch Loss: 0.000127
#   Epoch 15 | Batch 1400/2503 | Batch Loss: 0.000092
#   Epoch 15 | Batch 1500/2503 | Batch Loss: 0.000228
#   Epoch 15 | Batch 1600/2503 | Batch Loss: 0.000092
#   Epoch 15 | Batch 1700/2503 | Batch Loss: 0.000096
#   Epoch 15 | Batch 1800/2503 | Batch Loss: 0.000100
#   Epoch 15 | Batch 1900/2503 | Batch Loss: 0.000287
#   Epoch 15 | Batch 2000/2503 | Batch Loss: 0.000094
#   Epoch 15 | Batch 2100/2503 | Batch Loss: 0.000115
#   Epoch 15 | Batch 2200/2503 | Batch Loss: 0.000439
#   Epoch 15 | Batch 2300/2503 | Batch Loss: 0.000096
#   Epoch 15 | Batch 2400/2503 | Batch Loss: 0.000129
#   Epoch 15 | Batch 2500/2503 | Batch Loss: 0.000100
#
# Fine-tune Epoch 15/50 | Time: 259.0s
#   Train Loss: 0.000283 | Val MSE: 0.000412 *** New Best ***
# ------------------------------------------------------------
#   Epoch 16 | Batch 100/2503 | Batch Loss: 0.000128
#   Epoch 16 | Batch 200/2503 | Batch Loss: 0.000091
#   Epoch 16 | Batch 300/2503 | Batch Loss: 0.000075
#   Epoch 16 | Batch 400/2503 | Batch Loss: 0.000603
#   Epoch 16 | Batch 500/2503 | Batch Loss: 0.000124
#   Epoch 16 | Batch 600/2503 | Batch Loss: 0.000093
#   Epoch 16 | Batch 700/2503 | Batch Loss: 0.000093
#   Epoch 16 | Batch 800/2503 | Batch Loss: 0.000194
#   Epoch 16 | Batch 900/2503 | Batch Loss: 0.000158
#   Epoch 16 | Batch 1000/2503 | Batch Loss: 0.000095
#   Epoch 16 | Batch 1100/2503 | Batch Loss: 0.000099
#   Epoch 16 | Batch 1200/2503 | Batch Loss: 0.000088
#   Epoch 16 | Batch 1300/2503 | Batch Loss: 0.000084
#   Epoch 16 | Batch 1400/2503 | Batch Loss: 0.000858
#   Epoch 16 | Batch 1500/2503 | Batch Loss: 0.000122
#   Epoch 16 | Batch 1600/2503 | Batch Loss: 0.000131
#   Epoch 16 | Batch 1700/2503 | Batch Loss: 0.000812
#   Epoch 16 | Batch 1800/2503 | Batch Loss: 0.000095
#   Epoch 16 | Batch 1900/2503 | Batch Loss: 0.000094
#   Epoch 16 | Batch 2000/2503 | Batch Loss: 0.000089
#   Epoch 16 | Batch 2100/2503 | Batch Loss: 0.000544
#   Epoch 16 | Batch 2200/2503 | Batch Loss: 0.000083
#   Epoch 16 | Batch 2300/2503 | Batch Loss: 0.000115
#   Epoch 16 | Batch 2400/2503 | Batch Loss: 0.000091
#   Epoch 16 | Batch 2500/2503 | Batch Loss: 0.000131
#
# Fine-tune Epoch 16/50 | Time: 256.8s
#   Train Loss: 0.000274 | Val MSE: 0.000484
# ------------------------------------------------------------
#   Epoch 17 | Batch 100/2503 | Batch Loss: 0.000115
#   Epoch 17 | Batch 200/2503 | Batch Loss: 0.000131
#   Epoch 17 | Batch 300/2503 | Batch Loss: 0.000105
#   Epoch 17 | Batch 400/2503 | Batch Loss: 0.000737
#   Epoch 17 | Batch 500/2503 | Batch Loss: 0.000130
#   Epoch 17 | Batch 600/2503 | Batch Loss: 0.000177
#   Epoch 17 | Batch 700/2503 | Batch Loss: 0.000094
#   Epoch 17 | Batch 800/2503 | Batch Loss: 0.000108
#   Epoch 17 | Batch 900/2503 | Batch Loss: 0.000818
#   Epoch 17 | Batch 1000/2503 | Batch Loss: 0.000137
#   Epoch 17 | Batch 1100/2503 | Batch Loss: 0.000549
#   Epoch 17 | Batch 1200/2503 | Batch Loss: 0.000098
#   Epoch 17 | Batch 1300/2503 | Batch Loss: 0.000099
#   Epoch 17 | Batch 1400/2503 | Batch Loss: 0.000133
#   Epoch 17 | Batch 1500/2503 | Batch Loss: 0.000088
#   Epoch 17 | Batch 1600/2503 | Batch Loss: 0.000735
#   Epoch 17 | Batch 1700/2503 | Batch Loss: 0.000093
#   Epoch 17 | Batch 1800/2503 | Batch Loss: 0.000158
#   Epoch 17 | Batch 1900/2503 | Batch Loss: 0.000194
#   Epoch 17 | Batch 2000/2503 | Batch Loss: 0.000127
#   Epoch 17 | Batch 2100/2503 | Batch Loss: 0.000248
#   Epoch 17 | Batch 2200/2503 | Batch Loss: 0.000093
#   Epoch 17 | Batch 2300/2503 | Batch Loss: 0.000085
#   Epoch 17 | Batch 2400/2503 | Batch Loss: 0.000092
#   Epoch 17 | Batch 2500/2503 | Batch Loss: 0.000092
#
# Fine-tune Epoch 17/50 | Time: 258.2s
#   Train Loss: 0.000266 | Val MSE: 0.000452
# ------------------------------------------------------------
#   Epoch 18 | Batch 100/2503 | Batch Loss: 0.000346
#   Epoch 18 | Batch 200/2503 | Batch Loss: 0.000088
#   Epoch 18 | Batch 300/2503 | Batch Loss: 0.000092
#   Epoch 18 | Batch 400/2503 | Batch Loss: 0.000084
#   Epoch 18 | Batch 500/2503 | Batch Loss: 0.001407
#   Epoch 18 | Batch 600/2503 | Batch Loss: 0.000095
#   Epoch 18 | Batch 700/2503 | Batch Loss: 0.000093
#   Epoch 18 | Batch 800/2503 | Batch Loss: 0.000082
#   Epoch 18 | Batch 900/2503 | Batch Loss: 0.000244
#   Epoch 18 | Batch 1000/2503 | Batch Loss: 0.001603
#   Epoch 18 | Batch 1100/2503 | Batch Loss: 0.000090
#   Epoch 18 | Batch 1200/2503 | Batch Loss: 0.000092
#   Epoch 18 | Batch 1300/2503 | Batch Loss: 0.000099
#   Epoch 18 | Batch 1400/2503 | Batch Loss: 0.000970
#   Epoch 18 | Batch 1500/2503 | Batch Loss: 0.000085
#   Epoch 18 | Batch 1600/2503 | Batch Loss: 0.000110
#   Epoch 18 | Batch 1700/2503 | Batch Loss: 0.000092
#   Epoch 18 | Batch 1800/2503 | Batch Loss: 0.000092
#   Epoch 18 | Batch 1900/2503 | Batch Loss: 0.000148
#   Epoch 18 | Batch 2000/2503 | Batch Loss: 0.001494
#   Epoch 18 | Batch 2100/2503 | Batch Loss: 0.000112
#   Epoch 18 | Batch 2200/2503 | Batch Loss: 0.000445
#   Epoch 18 | Batch 2300/2503 | Batch Loss: 0.000094
#   Epoch 18 | Batch 2400/2503 | Batch Loss: 0.000098
#   Epoch 18 | Batch 2500/2503 | Batch Loss: 0.000095
#
# Fine-tune Epoch 18/50 | Time: 258.0s
#   Train Loss: 0.000259 | Val MSE: 0.000380 *** New Best ***
# ------------------------------------------------------------
#   Epoch 19 | Batch 100/2503 | Batch Loss: 0.000422
#   Epoch 19 | Batch 200/2503 | Batch Loss: 0.000098
#   Epoch 19 | Batch 300/2503 | Batch Loss: 0.000099
#   Epoch 19 | Batch 400/2503 | Batch Loss: 0.000699
#   Epoch 19 | Batch 500/2503 | Batch Loss: 0.000958
#   Epoch 19 | Batch 600/2503 | Batch Loss: 0.000644
#   Epoch 19 | Batch 700/2503 | Batch Loss: 0.000102
#   Epoch 19 | Batch 800/2503 | Batch Loss: 0.000082
#   Epoch 19 | Batch 900/2503 | Batch Loss: 0.000083
#   Epoch 19 | Batch 1000/2503 | Batch Loss: 0.000689
#   Epoch 19 | Batch 1100/2503 | Batch Loss: 0.000086
#   Epoch 19 | Batch 1200/2503 | Batch Loss: 0.000101
#   Epoch 19 | Batch 1300/2503 | Batch Loss: 0.000096
#   Epoch 19 | Batch 1400/2503 | Batch Loss: 0.001263
#   Epoch 19 | Batch 1500/2503 | Batch Loss: 0.000924
#   Epoch 19 | Batch 1600/2503 | Batch Loss: 0.000087
#   Epoch 19 | Batch 1700/2503 | Batch Loss: 0.000097
#   Epoch 19 | Batch 1800/2503 | Batch Loss: 0.000102
#   Epoch 19 | Batch 1900/2503 | Batch Loss: 0.000095
#   Epoch 19 | Batch 2000/2503 | Batch Loss: 0.000107
#   Epoch 19 | Batch 2100/2503 | Batch Loss: 0.000097
#   Epoch 19 | Batch 2200/2503 | Batch Loss: 0.000138
#   Epoch 19 | Batch 2300/2503 | Batch Loss: 0.000091
#   Epoch 19 | Batch 2400/2503 | Batch Loss: 0.000484
#   Epoch 19 | Batch 2500/2503 | Batch Loss: 0.000095
#
# Fine-tune Epoch 19/50 | Time: 256.8s
#   Train Loss: 0.000253 | Val MSE: 0.000318 *** New Best ***
# ------------------------------------------------------------
#   Epoch 20 | Batch 100/2503 | Batch Loss: 0.000104
#   Epoch 20 | Batch 200/2503 | Batch Loss: 0.000091
#   Epoch 20 | Batch 300/2503 | Batch Loss: 0.000101
#   Epoch 20 | Batch 400/2503 | Batch Loss: 0.000095
#   Epoch 20 | Batch 500/2503 | Batch Loss: 0.000251
#   Epoch 20 | Batch 600/2503 | Batch Loss: 0.000477
#   Epoch 20 | Batch 700/2503 | Batch Loss: 0.000097
#   Epoch 20 | Batch 800/2503 | Batch Loss: 0.001354
#   Epoch 20 | Batch 900/2503 | Batch Loss: 0.000093
#   Epoch 20 | Batch 1000/2503 | Batch Loss: 0.000097
#   Epoch 20 | Batch 1100/2503 | Batch Loss: 0.000278
#   Epoch 20 | Batch 1200/2503 | Batch Loss: 0.000885
#   Epoch 20 | Batch 1300/2503 | Batch Loss: 0.000111
#   Epoch 20 | Batch 1400/2503 | Batch Loss: 0.000096
#   Epoch 20 | Batch 1500/2503 | Batch Loss: 0.000094
#   Epoch 20 | Batch 1600/2503 | Batch Loss: 0.000104
#   Epoch 20 | Batch 1700/2503 | Batch Loss: 0.000168
#   Epoch 20 | Batch 1800/2503 | Batch Loss: 0.000090
#   Epoch 20 | Batch 1900/2503 | Batch Loss: 0.000508
#   Epoch 20 | Batch 2000/2503 | Batch Loss: 0.000082
#   Epoch 20 | Batch 2100/2503 | Batch Loss: 0.000126
#   Epoch 20 | Batch 2200/2503 | Batch Loss: 0.000104
#   Epoch 20 | Batch 2300/2503 | Batch Loss: 0.000079
#   Epoch 20 | Batch 2400/2503 | Batch Loss: 0.000514
#   Epoch 20 | Batch 2500/2503 | Batch Loss: 0.000097
#
# Fine-tune Epoch 20/50 | Time: 258.5s
#   Train Loss: 0.000247 | Val MSE: 0.000300 *** New Best ***
# ------------------------------------------------------------
#   Epoch 21 | Batch 100/2503 | Batch Loss: 0.000069
#   Epoch 21 | Batch 200/2503 | Batch Loss: 0.000091
#   Epoch 21 | Batch 300/2503 | Batch Loss: 0.000090
#   Epoch 21 | Batch 400/2503 | Batch Loss: 0.000115
#   Epoch 21 | Batch 500/2503 | Batch Loss: 0.000511
#   Epoch 21 | Batch 600/2503 | Batch Loss: 0.000098
#   Epoch 21 | Batch 700/2503 | Batch Loss: 0.000088
#   Epoch 21 | Batch 800/2503 | Batch Loss: 0.000082
#   Epoch 21 | Batch 900/2503 | Batch Loss: 0.000155
#   Epoch 21 | Batch 1000/2503 | Batch Loss: 0.000102
#   Epoch 21 | Batch 1100/2503 | Batch Loss: 0.000078
#   Epoch 21 | Batch 1200/2503 | Batch Loss: 0.001030
#   Epoch 21 | Batch 1300/2503 | Batch Loss: 0.000456
#   Epoch 21 | Batch 1400/2503 | Batch Loss: 0.000104
#   Epoch 21 | Batch 1500/2503 | Batch Loss: 0.000265
#   Epoch 21 | Batch 1600/2503 | Batch Loss: 0.000084
#   Epoch 21 | Batch 1700/2503 | Batch Loss: 0.001052
#   Epoch 21 | Batch 1800/2503 | Batch Loss: 0.000097
#   Epoch 21 | Batch 1900/2503 | Batch Loss: 0.000476
#   Epoch 21 | Batch 2000/2503 | Batch Loss: 0.000094
#   Epoch 21 | Batch 2100/2503 | Batch Loss: 0.000261
#   Epoch 21 | Batch 2200/2503 | Batch Loss: 0.000080
#   Epoch 21 | Batch 2300/2503 | Batch Loss: 0.000101
#   Epoch 21 | Batch 2400/2503 | Batch Loss: 0.000104
#   Epoch 21 | Batch 2500/2503 | Batch Loss: 0.000111
#
# Fine-tune Epoch 21/50 | Time: 258.1s
#   Train Loss: 0.000242 | Val MSE: 0.000306
# ------------------------------------------------------------
#   Epoch 22 | Batch 100/2503 | Batch Loss: 0.000089
#   Epoch 22 | Batch 200/2503 | Batch Loss: 0.000901
#   Epoch 22 | Batch 300/2503 | Batch Loss: 0.000090
#   Epoch 22 | Batch 400/2503 | Batch Loss: 0.000670
#   Epoch 22 | Batch 500/2503 | Batch Loss: 0.000540
#   Epoch 22 | Batch 600/2503 | Batch Loss: 0.000080
#   Epoch 22 | Batch 700/2503 | Batch Loss: 0.000373
#   Epoch 22 | Batch 800/2503 | Batch Loss: 0.000139
#   Epoch 22 | Batch 900/2503 | Batch Loss: 0.000216
#   Epoch 22 | Batch 1000/2503 | Batch Loss: 0.000516
#   Epoch 22 | Batch 1100/2503 | Batch Loss: 0.000097
#   Epoch 22 | Batch 1200/2503 | Batch Loss: 0.000444
#   Epoch 22 | Batch 1300/2503 | Batch Loss: 0.000086
#   Epoch 22 | Batch 1400/2503 | Batch Loss: 0.000216
#   Epoch 22 | Batch 1500/2503 | Batch Loss: 0.000083
#   Epoch 22 | Batch 1600/2503 | Batch Loss: 0.000206
#   Epoch 22 | Batch 1700/2503 | Batch Loss: 0.000989
#   Epoch 22 | Batch 1800/2503 | Batch Loss: 0.000082
#   Epoch 22 | Batch 1900/2503 | Batch Loss: 0.000087
#   Epoch 22 | Batch 2000/2503 | Batch Loss: 0.000104
#   Epoch 22 | Batch 2100/2503 | Batch Loss: 0.001016
#   Epoch 22 | Batch 2200/2503 | Batch Loss: 0.000089
#   Epoch 22 | Batch 2300/2503 | Batch Loss: 0.000073
#   Epoch 22 | Batch 2400/2503 | Batch Loss: 0.000374
#   Epoch 22 | Batch 2500/2503 | Batch Loss: 0.000101
#
# Fine-tune Epoch 22/50 | Time: 258.6s
#   Train Loss: 0.000236 | Val MSE: 0.000247 *** New Best ***
# ------------------------------------------------------------
#   Epoch 23 | Batch 100/2503 | Batch Loss: 0.000093
#   Epoch 23 | Batch 200/2503 | Batch Loss: 0.000453
#   Epoch 23 | Batch 300/2503 | Batch Loss: 0.000120
#   Epoch 23 | Batch 400/2503 | Batch Loss: 0.000076
#   Epoch 23 | Batch 500/2503 | Batch Loss: 0.000618
#   Epoch 23 | Batch 600/2503 | Batch Loss: 0.000548
#   Epoch 23 | Batch 700/2503 | Batch Loss: 0.000245
#   Epoch 23 | Batch 800/2503 | Batch Loss: 0.000102
#   Epoch 23 | Batch 900/2503 | Batch Loss: 0.001161
#   Epoch 23 | Batch 1000/2503 | Batch Loss: 0.000079
#   Epoch 23 | Batch 1100/2503 | Batch Loss: 0.000117
#   Epoch 23 | Batch 1200/2503 | Batch Loss: 0.000088
#   Epoch 23 | Batch 1300/2503 | Batch Loss: 0.000082
#   Epoch 23 | Batch 1400/2503 | Batch Loss: 0.000080
#   Epoch 23 | Batch 1500/2503 | Batch Loss: 0.000088
#   Epoch 23 | Batch 1600/2503 | Batch Loss: 0.000103
#   Epoch 23 | Batch 1700/2503 | Batch Loss: 0.000512
#   Epoch 23 | Batch 1800/2503 | Batch Loss: 0.000439
#   Epoch 23 | Batch 1900/2503 | Batch Loss: 0.000096
#   Epoch 23 | Batch 2000/2503 | Batch Loss: 0.000138
#   Epoch 23 | Batch 2100/2503 | Batch Loss: 0.000091
#   Epoch 23 | Batch 2200/2503 | Batch Loss: 0.000338
#   Epoch 23 | Batch 2300/2503 | Batch Loss: 0.000085
#   Epoch 23 | Batch 2400/2503 | Batch Loss: 0.000087
#   Epoch 23 | Batch 2500/2503 | Batch Loss: 0.000462
#
# Fine-tune Epoch 23/50 | Time: 257.3s
#   Train Loss: 0.000231 | Val MSE: 0.000273
# ------------------------------------------------------------
#   Epoch 24 | Batch 100/2503 | Batch Loss: 0.000083
#   Epoch 24 | Batch 200/2503 | Batch Loss: 0.000092
#   Epoch 24 | Batch 300/2503 | Batch Loss: 0.000082
#   Epoch 24 | Batch 400/2503 | Batch Loss: 0.000570
#   Epoch 24 | Batch 500/2503 | Batch Loss: 0.000873
#   Epoch 24 | Batch 600/2503 | Batch Loss: 0.000096
#   Epoch 24 | Batch 700/2503 | Batch Loss: 0.000461
#   Epoch 24 | Batch 800/2503 | Batch Loss: 0.000108
#   Epoch 24 | Batch 900/2503 | Batch Loss: 0.000089
#   Epoch 24 | Batch 1000/2503 | Batch Loss: 0.000098
#   Epoch 24 | Batch 1100/2503 | Batch Loss: 0.000091
#   Epoch 24 | Batch 1200/2503 | Batch Loss: 0.000077
#   Epoch 24 | Batch 1300/2503 | Batch Loss: 0.000099
#   Epoch 24 | Batch 1400/2503 | Batch Loss: 0.000069
#   Epoch 24 | Batch 1500/2503 | Batch Loss: 0.000079
#   Epoch 24 | Batch 1600/2503 | Batch Loss: 0.000134
#   Epoch 24 | Batch 1700/2503 | Batch Loss: 0.000084
#   Epoch 24 | Batch 1800/2503 | Batch Loss: 0.000578
#   Epoch 24 | Batch 1900/2503 | Batch Loss: 0.000092
#   Epoch 24 | Batch 2000/2503 | Batch Loss: 0.000103
#   Epoch 24 | Batch 2100/2503 | Batch Loss: 0.000103
#   Epoch 24 | Batch 2200/2503 | Batch Loss: 0.000099
#   Epoch 24 | Batch 2300/2503 | Batch Loss: 0.000082
#   Epoch 24 | Batch 2400/2503 | Batch Loss: 0.000116
#   Epoch 24 | Batch 2500/2503 | Batch Loss: 0.000100
#
# Fine-tune Epoch 24/50 | Time: 257.4s
#   Train Loss: 0.000226 | Val MSE: 0.000231 *** New Best ***
# ------------------------------------------------------------
#   Epoch 25 | Batch 100/2503 | Batch Loss: 0.000084
#   Epoch 25 | Batch 200/2503 | Batch Loss: 0.000126
#   Epoch 25 | Batch 300/2503 | Batch Loss: 0.000092
#   Epoch 25 | Batch 400/2503 | Batch Loss: 0.000182
#   Epoch 25 | Batch 500/2503 | Batch Loss: 0.000094
#   Epoch 25 | Batch 600/2503 | Batch Loss: 0.000451
#   Epoch 25 | Batch 700/2503 | Batch Loss: 0.000093
#   Epoch 25 | Batch 800/2503 | Batch Loss: 0.000091
#   Epoch 25 | Batch 900/2503 | Batch Loss: 0.000086
#   Epoch 25 | Batch 1000/2503 | Batch Loss: 0.000083
#   Epoch 25 | Batch 1100/2503 | Batch Loss: 0.000081
#   Epoch 25 | Batch 1200/2503 | Batch Loss: 0.000094
# ...
#   Epoch 28 | Batch 800/2503 | Batch Loss: 0.000099
#   Epoch 28 | Batch 900/2503 | Batch Loss: 0.000095
#   Epoch 28 | Batch 1000/2503 | Batch Loss: 0.000105
#   Epoch 28 | Batch 1100/2503 | Batch Loss: 0.000090
#   Epoch 28 | Batch 1200/2503 | Batch Loss: 0.000095
#   Epoch 28 | Batch 1300/2503 | Batch Loss: 0.000355
#   Epoch 28 | Batch 1400/2503 | Batch Loss: 0.000088
#   Epoch 28 | Batch 1500/2503 | Batch Loss: 0.000364
#   Epoch 28 | Batch 1600/2503 | Batch Loss: 0.000089
#   Epoch 28 | Batch 1700/2503 | Batch Loss: 0.000099
#   Epoch 28 | Batch 1800/2503 | Batch Loss: 0.000080
#   Epoch 28 | Batch 1900/2503 | Batch Loss: 0.000490
#   Epoch 28 | Batch 2000/2503 | Batch Loss: 0.000080
#   Epoch 28 | Batch 2100/2503 | Batch Loss: 0.000116
#   Epoch 28 | Batch 2200/2503 | Batch Loss: 0.000091
#   Epoch 28 | Batch 2300/2503 | Batch Loss: 0.000080
#   Epoch 28 | Batch 2400/2503 | Batch Loss: 0.000096
#   Epoch 28 | Batch 2500/2503 | Batch Loss: 0.000080
#
# Fine-tune Epoch 28/50 | Time: 256.8s
#   Train Loss: 0.000213 | Val MSE: 0.000251
# ------------------------------------------------------------
#   Epoch 29 | Batch 100/2503 | Batch Loss: 0.000090
#   Epoch 29 | Batch 200/2503 | Batch Loss: 0.000102
#   Epoch 29 | Batch 300/2503 | Batch Loss: 0.000636
#   Epoch 29 | Batch 400/2503 | Batch Loss: 0.000076
#   Epoch 29 | Batch 500/2503 | Batch Loss: 0.000127
#   Epoch 29 | Batch 600/2503 | Batch Loss: 0.000526
#   Epoch 29 | Batch 700/2503 | Batch Loss: 0.000167
#   Epoch 29 | Batch 800/2503 | Batch Loss: 0.000093
#   Epoch 29 | Batch 900/2503 | Batch Loss: 0.000093
#   Epoch 29 | Batch 1000/2503 | Batch Loss: 0.000432
#   Epoch 29 | Batch 1100/2503 | Batch Loss: 0.003725
#   Epoch 29 | Batch 1200/2503 | Batch Loss: 0.000420
#   Epoch 29 | Batch 1300/2503 | Batch Loss: 0.000095
#   Epoch 29 | Batch 1400/2503 | Batch Loss: 0.000555
#   Epoch 29 | Batch 1500/2503 | Batch Loss: 0.000072
#   Epoch 29 | Batch 1600/2503 | Batch Loss: 0.000086
#   Epoch 29 | Batch 1700/2503 | Batch Loss: 0.000080
#   Epoch 29 | Batch 1800/2503 | Batch Loss: 0.000105
#   Epoch 29 | Batch 1900/2503 | Batch Loss: 0.000104
#   Epoch 29 | Batch 2000/2503 | Batch Loss: 0.000652
#   Epoch 29 | Batch 2100/2503 | Batch Loss: 0.000096
#   Epoch 29 | Batch 2200/2503 | Batch Loss: 0.000078
#   Epoch 29 | Batch 2300/2503 | Batch Loss: 0.000421
#   Epoch 29 | Batch 2400/2503 | Batch Loss: 0.000477
#   Epoch 29 | Batch 2500/2503 | Batch Loss: 0.000073
#
# Fine-tune Epoch 29/50 | Time: 257.4s
#   Train Loss: 0.000209 | Val MSE: 0.000201 *** New Best ***
# ------------------------------------------------------------
#   Epoch 30 | Batch 100/2503 | Batch Loss: 0.000106
#   Epoch 30 | Batch 200/2503 | Batch Loss: 0.000584
#   Epoch 30 | Batch 300/2503 | Batch Loss: 0.000084
#   Epoch 30 | Batch 400/2503 | Batch Loss: 0.000088
#   Epoch 30 | Batch 500/2503 | Batch Loss: 0.000080
#   Epoch 30 | Batch 600/2503 | Batch Loss: 0.000111
#   Epoch 30 | Batch 700/2503 | Batch Loss: 0.000668
#   Epoch 30 | Batch 800/2503 | Batch Loss: 0.000119
#   Epoch 30 | Batch 900/2503 | Batch Loss: 0.000116
#   Epoch 30 | Batch 1000/2503 | Batch Loss: 0.000086
#   Epoch 30 | Batch 1100/2503 | Batch Loss: 0.000130
#   Epoch 30 | Batch 1200/2503 | Batch Loss: 0.000587
#   Epoch 30 | Batch 1300/2503 | Batch Loss: 0.000097
#   Epoch 30 | Batch 1400/2503 | Batch Loss: 0.000197
#   Epoch 30 | Batch 1500/2503 | Batch Loss: 0.000080
#   Epoch 30 | Batch 1600/2503 | Batch Loss: 0.000665
#   Epoch 30 | Batch 1700/2503 | Batch Loss: 0.000077
#   Epoch 30 | Batch 1800/2503 | Batch Loss: 0.000110
#   Epoch 30 | Batch 1900/2503 | Batch Loss: 0.000112
#   Epoch 30 | Batch 2000/2503 | Batch Loss: 0.000450
#   Epoch 30 | Batch 2100/2503 | Batch Loss: 0.000088
#   Epoch 30 | Batch 2200/2503 | Batch Loss: 0.000078
#   Epoch 30 | Batch 2300/2503 | Batch Loss: 0.000090
#   Epoch 30 | Batch 2400/2503 | Batch Loss: 0.000095
#   Epoch 30 | Batch 2500/2503 | Batch Loss: 0.000095
#
# Fine-tune Epoch 30/50 | Time: 256.9s
#   Train Loss: 0.000205 | Val MSE: 0.000256
# ------------------------------------------------------------
#   Epoch 31 | Batch 100/2503 | Batch Loss: 0.000705
#   Epoch 31 | Batch 200/2503 | Batch Loss: 0.000576
#   Epoch 31 | Batch 300/2503 | Batch Loss: 0.000083
#   Epoch 31 | Batch 400/2503 | Batch Loss: 0.000101
#   Epoch 31 | Batch 500/2503 | Batch Loss: 0.000086
#   Epoch 31 | Batch 600/2503 | Batch Loss: 0.000100
#   Epoch 31 | Batch 700/2503 | Batch Loss: 0.000095
#   Epoch 31 | Batch 800/2503 | Batch Loss: 0.002000
#   Epoch 31 | Batch 900/2503 | Batch Loss: 0.001436
#   Epoch 31 | Batch 1000/2503 | Batch Loss: 0.000376
#   Epoch 31 | Batch 1100/2503 | Batch Loss: 0.000091
#   Epoch 31 | Batch 1200/2503 | Batch Loss: 0.000093
#   Epoch 31 | Batch 1300/2503 | Batch Loss: 0.000085
#   Epoch 31 | Batch 1400/2503 | Batch Loss: 0.000095
#   Epoch 31 | Batch 1500/2503 | Batch Loss: 0.000825
#   Epoch 31 | Batch 1600/2503 | Batch Loss: 0.000089
#   Epoch 31 | Batch 1700/2503 | Batch Loss: 0.001036
#   Epoch 31 | Batch 1800/2503 | Batch Loss: 0.000328
#   Epoch 31 | Batch 1900/2503 | Batch Loss: 0.000089
#   Epoch 31 | Batch 2000/2503 | Batch Loss: 0.000130
#   Epoch 31 | Batch 2100/2503 | Batch Loss: 0.000077
#   Epoch 31 | Batch 2200/2503 | Batch Loss: 0.000538
#   Epoch 31 | Batch 2300/2503 | Batch Loss: 0.000124
#   Epoch 31 | Batch 2400/2503 | Batch Loss: 0.000088
#   Epoch 31 | Batch 2500/2503 | Batch Loss: 0.000085
#
# Fine-tune Epoch 31/50 | Time: 258.4s
#   Train Loss: 0.000204 | Val MSE: 0.000240
# ------------------------------------------------------------
#   Epoch 32 | Batch 100/2503 | Batch Loss: 0.000096
#   Epoch 32 | Batch 200/2503 | Batch Loss: 0.000482
#   Epoch 32 | Batch 300/2503 | Batch Loss: 0.000084
#   Epoch 32 | Batch 400/2503 | Batch Loss: 0.000084
#   Epoch 32 | Batch 500/2503 | Batch Loss: 0.000506
#   Epoch 32 | Batch 600/2503 | Batch Loss: 0.000073
#   Epoch 32 | Batch 700/2503 | Batch Loss: 0.000088
#   Epoch 32 | Batch 800/2503 | Batch Loss: 0.000084
#   Epoch 32 | Batch 900/2503 | Batch Loss: 0.000092
#   Epoch 32 | Batch 1000/2503 | Batch Loss: 0.000457
#   Epoch 32 | Batch 1100/2503 | Batch Loss: 0.000097
#   Epoch 32 | Batch 1200/2503 | Batch Loss: 0.000086
#   Epoch 32 | Batch 1300/2503 | Batch Loss: 0.000248
#   Epoch 32 | Batch 1400/2503 | Batch Loss: 0.000458
#   Epoch 32 | Batch 1500/2503 | Batch Loss: 0.000087
#   Epoch 32 | Batch 1600/2503 | Batch Loss: 0.000360
#   Epoch 32 | Batch 1700/2503 | Batch Loss: 0.000320
#   Epoch 32 | Batch 1800/2503 | Batch Loss: 0.000080
#   Epoch 32 | Batch 1900/2503 | Batch Loss: 0.000102
#   Epoch 32 | Batch 2000/2503 | Batch Loss: 0.000115
#   Epoch 32 | Batch 2100/2503 | Batch Loss: 0.000504
#   Epoch 32 | Batch 2200/2503 | Batch Loss: 0.000075
#   Epoch 32 | Batch 2300/2503 | Batch Loss: 0.000081
#   Epoch 32 | Batch 2400/2503 | Batch Loss: 0.000487
#   Epoch 32 | Batch 2500/2503 | Batch Loss: 0.000095
#
# Fine-tune Epoch 32/50 | Time: 258.0s
#   Train Loss: 0.000200 | Val MSE: 0.000176 *** New Best ***
# ------------------------------------------------------------
#   Epoch 33 | Batch 100/2503 | Batch Loss: 0.000111
#   Epoch 33 | Batch 200/2503 | Batch Loss: 0.000242
#   Epoch 33 | Batch 300/2503 | Batch Loss: 0.000080
#   Epoch 33 | Batch 400/2503 | Batch Loss: 0.000100
#   Epoch 33 | Batch 500/2503 | Batch Loss: 0.000920
#   Epoch 33 | Batch 600/2503 | Batch Loss: 0.000099
#   Epoch 33 | Batch 700/2503 | Batch Loss: 0.000086
#   Epoch 33 | Batch 800/2503 | Batch Loss: 0.000851
#   Epoch 33 | Batch 900/2503 | Batch Loss: 0.000108
#   Epoch 33 | Batch 1000/2503 | Batch Loss: 0.000086
#   Epoch 33 | Batch 1100/2503 | Batch Loss: 0.000089
#   Epoch 33 | Batch 1200/2503 | Batch Loss: 0.000106
#   Epoch 33 | Batch 1300/2503 | Batch Loss: 0.000523
#   Epoch 33 | Batch 1400/2503 | Batch Loss: 0.000092
#   Epoch 33 | Batch 1500/2503 | Batch Loss: 0.000647
#   Epoch 33 | Batch 1600/2503 | Batch Loss: 0.000140
#   Epoch 33 | Batch 1700/2503 | Batch Loss: 0.000178
#   Epoch 33 | Batch 1800/2503 | Batch Loss: 0.000082
#   Epoch 33 | Batch 1900/2503 | Batch Loss: 0.000080
#   Epoch 33 | Batch 2000/2503 | Batch Loss: 0.000080
#   Epoch 33 | Batch 2100/2503 | Batch Loss: 0.000400
#   Epoch 33 | Batch 2200/2503 | Batch Loss: 0.000317
#   Epoch 33 | Batch 2300/2503 | Batch Loss: 0.000112
#   Epoch 33 | Batch 2400/2503 | Batch Loss: 0.000081
#   Epoch 33 | Batch 2500/2503 | Batch Loss: 0.000086
#
# Fine-tune Epoch 33/50 | Time: 258.1s
#   Train Loss: 0.000198 | Val MSE: 0.000233
# ------------------------------------------------------------
#   Epoch 34 | Batch 100/2503 | Batch Loss: 0.000090
#   Epoch 34 | Batch 200/2503 | Batch Loss: 0.000101
#   Epoch 34 | Batch 300/2503 | Batch Loss: 0.000102
#   Epoch 34 | Batch 400/2503 | Batch Loss: 0.000140
#   Epoch 34 | Batch 500/2503 | Batch Loss: 0.000398
#   Epoch 34 | Batch 600/2503 | Batch Loss: 0.000109
#   Epoch 34 | Batch 700/2503 | Batch Loss: 0.000094
#   Epoch 34 | Batch 800/2503 | Batch Loss: 0.000091
#   Epoch 34 | Batch 900/2503 | Batch Loss: 0.000096
#   Epoch 34 | Batch 1000/2503 | Batch Loss: 0.000077
#   Epoch 34 | Batch 1100/2503 | Batch Loss: 0.000089
#   Epoch 34 | Batch 1200/2503 | Batch Loss: 0.000218
#   Epoch 34 | Batch 1300/2503 | Batch Loss: 0.000093
#   Epoch 34 | Batch 1400/2503 | Batch Loss: 0.000091
#   Epoch 34 | Batch 1500/2503 | Batch Loss: 0.000082
#   Epoch 34 | Batch 1600/2503 | Batch Loss: 0.000437
#   Epoch 34 | Batch 1700/2503 | Batch Loss: 0.000091
#   Epoch 34 | Batch 1800/2503 | Batch Loss: 0.000425
#   Epoch 34 | Batch 1900/2503 | Batch Loss: 0.000135
#   Epoch 34 | Batch 2000/2503 | Batch Loss: 0.001134
#   Epoch 34 | Batch 2100/2503 | Batch Loss: 0.000084
#   Epoch 34 | Batch 2200/2503 | Batch Loss: 0.000082
#   Epoch 34 | Batch 2300/2503 | Batch Loss: 0.000605
#   Epoch 34 | Batch 2400/2503 | Batch Loss: 0.000381
#   Epoch 34 | Batch 2500/2503 | Batch Loss: 0.000101
#
# Fine-tune Epoch 34/50 | Time: 258.1s
#   Train Loss: 0.000195 | Val MSE: 0.000198
# ------------------------------------------------------------
#   Epoch 35 | Batch 100/2503 | Batch Loss: 0.000098
#   Epoch 35 | Batch 200/2503 | Batch Loss: 0.000097
#   Epoch 35 | Batch 300/2503 | Batch Loss: 0.000089
#   Epoch 35 | Batch 400/2503 | Batch Loss: 0.000100
#   Epoch 35 | Batch 500/2503 | Batch Loss: 0.000101
#   Epoch 35 | Batch 600/2503 | Batch Loss: 0.000118
#   Epoch 35 | Batch 700/2503 | Batch Loss: 0.000097
#   Epoch 35 | Batch 800/2503 | Batch Loss: 0.000099
#   Epoch 35 | Batch 900/2503 | Batch Loss: 0.000088
#   Epoch 35 | Batch 1000/2503 | Batch Loss: 0.000105
#   Epoch 35 | Batch 1100/2503 | Batch Loss: 0.000083
#   Epoch 35 | Batch 1200/2503 | Batch Loss: 0.000561
#   Epoch 35 | Batch 1300/2503 | Batch Loss: 0.000097
#   Epoch 35 | Batch 1400/2503 | Batch Loss: 0.000070
#   Epoch 35 | Batch 1500/2503 | Batch Loss: 0.000620
#   Epoch 35 | Batch 1600/2503 | Batch Loss: 0.000109
#   Epoch 35 | Batch 1700/2503 | Batch Loss: 0.000084
#   Epoch 35 | Batch 1800/2503 | Batch Loss: 0.000076
#   Epoch 35 | Batch 1900/2503 | Batch Loss: 0.000431
#   Epoch 35 | Batch 2000/2503 | Batch Loss: 0.000435
#   Epoch 35 | Batch 2100/2503 | Batch Loss: 0.000083
#   Epoch 35 | Batch 2200/2503 | Batch Loss: 0.000071
#   Epoch 35 | Batch 2300/2503 | Batch Loss: 0.000445
#   Epoch 35 | Batch 2400/2503 | Batch Loss: 0.000086
#   Epoch 35 | Batch 2500/2503 | Batch Loss: 0.000389
#
# Fine-tune Epoch 35/50 | Time: 258.5s
#   Train Loss: 0.000193 | Val MSE: 0.000154 *** New Best ***
# ------------------------------------------------------------
#   Epoch 36 | Batch 100/2503 | Batch Loss: 0.000104
#   Epoch 36 | Batch 200/2503 | Batch Loss: 0.000107
#   Epoch 36 | Batch 300/2503 | Batch Loss: 0.000522
#   Epoch 36 | Batch 400/2503 | Batch Loss: 0.000080
#   Epoch 36 | Batch 500/2503 | Batch Loss: 0.000170
#   Epoch 36 | Batch 600/2503 | Batch Loss: 0.000191
#   Epoch 36 | Batch 700/2503 | Batch Loss: 0.000076
#   Epoch 36 | Batch 800/2503 | Batch Loss: 0.000715
#   Epoch 36 | Batch 900/2503 | Batch Loss: 0.000075
#   Epoch 36 | Batch 1000/2503 | Batch Loss: 0.000087
#   Epoch 36 | Batch 1100/2503 | Batch Loss: 0.000087
#   Epoch 36 | Batch 1200/2503 | Batch Loss: 0.000079
#   Epoch 36 | Batch 1300/2503 | Batch Loss: 0.000078
#   Epoch 36 | Batch 1400/2503 | Batch Loss: 0.000524
#   Epoch 36 | Batch 1500/2503 | Batch Loss: 0.000092
#   Epoch 36 | Batch 1600/2503 | Batch Loss: 0.000139
#   Epoch 36 | Batch 1700/2503 | Batch Loss: 0.000080
#   Epoch 36 | Batch 1800/2503 | Batch Loss: 0.000086
#   Epoch 36 | Batch 1900/2503 | Batch Loss: 0.000342
#   Epoch 36 | Batch 2000/2503 | Batch Loss: 0.000431
#   Epoch 36 | Batch 2100/2503 | Batch Loss: 0.000079
#   Epoch 36 | Batch 2200/2503 | Batch Loss: 0.000093
#   Epoch 36 | Batch 2300/2503 | Batch Loss: 0.000091
#   Epoch 36 | Batch 2400/2503 | Batch Loss: 0.000477
#   Epoch 36 | Batch 2500/2503 | Batch Loss: 0.000342
#
# Fine-tune Epoch 36/50 | Time: 258.6s
#   Train Loss: 0.000192 | Val MSE: 0.000158
# ------------------------------------------------------------
#   Epoch 37 | Batch 100/2503 | Batch Loss: 0.000108
#   Epoch 37 | Batch 200/2503 | Batch Loss: 0.003746
#   Epoch 37 | Batch 300/2503 | Batch Loss: 0.000312
#   Epoch 37 | Batch 400/2503 | Batch Loss: 0.000092
#   Epoch 37 | Batch 500/2503 | Batch Loss: 0.000088
#   Epoch 37 | Batch 600/2503 | Batch Loss: 0.000183
#   Epoch 37 | Batch 700/2503 | Batch Loss: 0.000415
#   Epoch 37 | Batch 800/2503 | Batch Loss: 0.000082
#   Epoch 37 | Batch 900/2503 | Batch Loss: 0.000604
#   Epoch 37 | Batch 1000/2503 | Batch Loss: 0.000086
#   Epoch 37 | Batch 1100/2503 | Batch Loss: 0.000084
#   Epoch 37 | Batch 1200/2503 | Batch Loss: 0.000295
#   Epoch 37 | Batch 1300/2503 | Batch Loss: 0.000328
#   Epoch 37 | Batch 1400/2503 | Batch Loss: 0.000085
#   Epoch 37 | Batch 1500/2503 | Batch Loss: 0.000099
#   Epoch 37 | Batch 1600/2503 | Batch Loss: 0.000926
#   Epoch 37 | Batch 1700/2503 | Batch Loss: 0.000115
#   Epoch 37 | Batch 1800/2503 | Batch Loss: 0.000105
#   Epoch 37 | Batch 1900/2503 | Batch Loss: 0.000104
#   Epoch 37 | Batch 2000/2503 | Batch Loss: 0.000338
#   Epoch 37 | Batch 2100/2503 | Batch Loss: 0.000098
#   Epoch 37 | Batch 2200/2503 | Batch Loss: 0.000103
#   Epoch 37 | Batch 2300/2503 | Batch Loss: 0.000093
#   Epoch 37 | Batch 2400/2503 | Batch Loss: 0.000186
#   Epoch 37 | Batch 2500/2503 | Batch Loss: 0.000110
#
# Fine-tune Epoch 37/50 | Time: 258.5s
#   Train Loss: 0.000190 | Val MSE: 0.000186
# ------------------------------------------------------------
#   Epoch 38 | Batch 100/2503 | Batch Loss: 0.000099
#   Epoch 38 | Batch 200/2503 | Batch Loss: 0.000310
#   Epoch 38 | Batch 300/2503 | Batch Loss: 0.000095
#   Epoch 38 | Batch 400/2503 | Batch Loss: 0.000133
#   Epoch 38 | Batch 500/2503 | Batch Loss: 0.000086
#   Epoch 38 | Batch 600/2503 | Batch Loss: 0.000107
#   Epoch 38 | Batch 700/2503 | Batch Loss: 0.000116
#   Epoch 38 | Batch 800/2503 | Batch Loss: 0.000106
#   Epoch 38 | Batch 900/2503 | Batch Loss: 0.000312
#   Epoch 38 | Batch 1000/2503 | Batch Loss: 0.000669
#   Epoch 38 | Batch 1100/2503 | Batch Loss: 0.000106
#   Epoch 38 | Batch 1200/2503 | Batch Loss: 0.000092
#   Epoch 38 | Batch 1300/2503 | Batch Loss: 0.000086
#   Epoch 38 | Batch 1400/2503 | Batch Loss: 0.000090
#   Epoch 38 | Batch 1500/2503 | Batch Loss: 0.000536
#   Epoch 38 | Batch 1600/2503 | Batch Loss: 0.000391
#   Epoch 38 | Batch 1700/2503 | Batch Loss: 0.000115
#   Epoch 38 | Batch 1800/2503 | Batch Loss: 0.000088
#   Epoch 38 | Batch 1900/2503 | Batch Loss: 0.000078
#   Epoch 38 | Batch 2000/2503 | Batch Loss: 0.000344
#   Epoch 38 | Batch 2100/2503 | Batch Loss: 0.000098
#   Epoch 38 | Batch 2200/2503 | Batch Loss: 0.000199
#   Epoch 38 | Batch 2300/2503 | Batch Loss: 0.000313
#   Epoch 38 | Batch 2400/2503 | Batch Loss: 0.000089
#   Epoch 38 | Batch 2500/2503 | Batch Loss: 0.000099
#
# Fine-tune Epoch 38/50 | Time: 259.0s
#   Train Loss: 0.000188 | Val MSE: 0.000161
# ------------------------------------------------------------
#
# *** Early stopping triggered at epoch 38 ***
#
# ============================================================
# TRAINING COMPLETE!
# Best Validation MSE: 0.000154
# ============================================================
#
# ============================================================
# RUNNING FINAL TEST SET EVALUATION
# ============================================================
# Final Test MSE: 0.000404
#
# Saving loss history to 'loss_history.txt'...
# Generating loss curve plot 'loss_plot.png'...
# Execution Finished.
